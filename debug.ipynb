# %%
# def check_single_stock(ticker, config):
#     import yfinance as yf
    
#     print(f"\n🔎 Checking {ticker} ...")
#     stock = yf.Ticker(ticker)

#     try:
#         expiry = stock.options[0]  # first expiry
#         opt_chain = stock.option_chain(expiry)
#         options = opt_chain.calls  # you can also check puts
#         options["type"] = "call"
#     except Exception as e:
#         print(f"❌ Could not fetch options for {ticker}: {e}")
#         return

#     results = []
#     for _, row in options.iterrows():
#         score = 0
#         notes = []

#         # Volume filter
#         if row["volume"] >= config["MIN_OPTION_VOLUME"]:
#             notes.append("✅ Volume OK")
#             score += 1
#         else:
#             notes.append("❌ Volume Low")

#         # Open Interest filter
#         if row["openInterest"] >= config["MIN_OPTION_OPEN_INTEREST"]:
#             notes.append("✅ OI OK")
#             score += 1
#         else:
#             notes.append("❌ OI Low")

#         # Delta filter (if available)
#         if "delta" in row and row["delta"] is not None:
#             if config["MIN_DELTA"] <= row["delta"] <= config["MAX_DELTA"]:
#                 notes.append("✅ Delta OK")
#                 score += 1
#             else:
#                 notes.append("❌ Delta Out of Range")
#         else:
#             notes.append("⚠️ Delta Not Available")

#         # Premium filter
#         premium_limit = (config["MAX_PREMIUM_PER_CONTRACT"] or float("inf")) / 100
#         if row["lastPrice"] <= premium_limit:
#             notes.append("✅ Premium OK")
#             score += 1
#         else:
#             notes.append("❌ Premium High")

#         results.append({
#             "strike": row["strike"],
#             "lastPrice": row["lastPrice"],
#             "score": score,
#             "notes": "; ".join(notes)
#         })

#     return results

# %%
# #check_stock("SNOW")
# res = check_single_stock("SNOW", CONFIG)
# for r in res[:5]:  # show top 5 strikes
#     print(f"Strike {r['strike']} | Price {r['lastPrice']} | Score {r['score']} | {r['notes']}")
# Out:
# 🔎 Checking SNOW ...
# Strike 125.0 | Price 74.11 | Score 0 | ❌ Volume Low; ❌ OI Low; ⚠️ Delta Not Available; ❌ Premium High
# Strike 145.0 | Price 50.57 | Score 0 | ❌ Volume Low; ❌ OI Low; ⚠️ Delta Not Available; ❌ Premium High
# Strike 150.0 | Price 67.31 | Score 0 | ❌ Volume Low; ❌ OI Low; ⚠️ Delta Not Available; ❌ Premium High
# Strike 155.0 | Price 45.1 | Score 1 | ❌ Volume Low; ❌ OI Low; ⚠️ Delta Not Available; ✅ Premium OK
# Strike 160.0 | Price 38.41 | Score 1 | ❌ Volume Low; ❌ OI Low; ⚠️ Delta Not Available; ✅ Premium OK

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from tradingview_ta import TA_Handler, Interval
from tqdm import tqdm
from scipy.stats import norm
from concurrent.futures import ThreadPoolExecutor, as_completed
import datetime
import time
import logging
import matplotlib.pyplot as plt
import warnings
from tenacity import retry, stop_after_attempt, wait_exponential
import json

# Dependency check
required_libs = ['yfinance', 'pandas', 'numpy', 'tradingview_ta', 'tqdm', 'scipy', 'matplotlib', 'tenacity']
for lib in required_libs:
    try:
        __import__(lib)
    except ImportError:
        print(f"Error: {lib} is not installed. Install it using 'pip install {lib}'")
        exit(1)

warnings.filterwarnings('ignore')
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# ------------------------------
# CONFIGURATION
# ------------------------------
CONFIG = {
    'MAX_STOCK_PRICE_TO_OWN_100': None,
    'MAX_PREMIUM_PER_CONTRACT': None,  # Relaxed from 50000
    'EARNINGS_WITHIN_DAYS': 180,         # Relaxed from 90 to 180 days
    'REQUIRE_TV_BUY': False,             # Allow all TV ratings
    'EXPIRY_DAYS_MIN': 0,                # Relaxed from 5 (allow same-day expiries)
    'EXPIRY_DAYS_MAX': 180,              # Relaxed from 90
    'MAX_WORKERS': 8,
    'TOP_N': 50,
    'SCORE_WEIGHTS': {'tv': 0.3, 'upside': 0.3, 'delta': 0.2, 'iv': 0.2},
    'MIN_OPTION_VOLUME': 1,              # Relaxed from 5
    'MIN_OPTION_OPEN_INTEREST': 10,      # Relaxed from 50
    'MIN_DELTA': 0.1,                    # Relaxed from 0.2
    'MAX_DELTA': 0.9,                    # Relaxed from 0.8
    'RISK_FREE_RATE': 0.02,
    'DIVIDEND_YIELD': 0.0,
    'MIN_MARKET_CAP': 100_000_000       # New: Minimum market cap $100M
}

# ------------------------------
# Track filter failures
# ------------------------------
FILTER_FAILURES = {
    'tv_rating': 0,
    'price': 0,
    'earnings': 0,
    'options_empty': 0,
    'options_filtered': 0,
    'api_error': 0,
    'market_cap': 0
}

# ------------------------------
# Timer decorator
# ------------------------------
def timed(func):
    def wrapper(*args, **kwargs):
        start = time.time()
        result = func(*args, **kwargs)
        end = time.time()
        logging.info(f"Execution time for {func.__name__}: {end - start:.2f} seconds")
        return result
    return wrapper

# ------------------------------
# Get TradingView rating
# ------------------------------
@retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=4, max=10))
def get_tv_rating(symbol):
    try:
        handler = TA_Handler(symbol=symbol, screener='america', exchange='NASDAQ', interval=Interval.INTERVAL_1_DAY)
        analysis = handler.get_analysis()
        rating = analysis.summary['RECOMMEND']
        score_map = {'STRONG_BUY': 1.0, 'BUY': 0.8, 'NEUTRAL': 0.5, 'SELL': 0.2, 'STRONG_SELL': 0.0}
        return {'rating': rating, 'score': score_map.get(rating, 0.5)}
    except Exception as e:
        FILTER_FAILURES['api_error'] += 1
        logging.warning(f"Failed to get TradingView rating for {symbol}: {str(e)}")
        return {'rating': None, 'score': 0.5}

# ------------------------------
# Fetch Yahoo Finance data
# ------------------------------
def get_yf_data(symbol):
    try:
        stock = yf.Ticker(symbol)
        info = stock.info
        current_price = info.get('regularMarketPrice') or info.get('currentPrice')
        # Price filter
        if not current_price:
            FILTER_FAILURES['price'] += 1
            logging.info(f"Skipping {symbol}: Invalid price")
            return None
        if CONFIG['MAX_STOCK_PRICE_TO_OWN_100'] is not None and current_price * 100 > CONFIG['MAX_STOCK_PRICE_TO_OWN_100']:
            FILTER_FAILURES['price'] += 1
            logging.info(f"Skipping {symbol}: Too expensive (>{CONFIG['MAX_STOCK_PRICE_TO_OWN_100']})")
            return None
        
        # Market cap filter
        market_cap = info.get('marketCap')
        if market_cap is None or market_cap < CONFIG['MIN_MARKET_CAP']:
            FILTER_FAILURES['market_cap'] += 1
            logging.info(f"Skipping {symbol}: Market cap too low or missing")
            return None
        target_price = info.get('targetMeanPrice')
        # Earnings date handling
        earnings_date = None
        if 'earningsDate' in info and info['earningsDate']:
            earnings_date = info['earningsDate']
            if isinstance(earnings_date, list):
                earnings_date = earnings_date[0] if earnings_date else None
            try:
                earnings_date = pd.to_datetime(earnings_date)
                days_until_earnings = (earnings_date - datetime.datetime.now()).days
                if CONFIG['EARNINGS_WITHIN_DAYS'] is not None and days_until_earnings > CONFIG['EARNINGS_WITHIN_DAYS']:
                    FILTER_FAILURES['earnings'] += 1
                    logging.info(f"Skipping {symbol}: Earnings too far ({days_until_earnings} days)")
                    return None
            except (ValueError, TypeError):
                logging.warning(f"Invalid earnings date for {symbol}, treating as None")
                earnings_date = None
        # Options
        options_df = pd.DataFrame()
        options = stock.options
        if not options:
            FILTER_FAILURES['options_empty'] += 1
            logging.info(f"Skipping {symbol}: No options available")
            return None
        option_data = []
        for exp in options:
            days_to_expiry = (pd.to_datetime(exp) - datetime.datetime.now()).days
            # Expiry filter
            if CONFIG['EXPIRY_DAYS_MIN'] is not None and days_to_expiry < CONFIG['EXPIRY_DAYS_MIN']:
                continue
            if CONFIG['EXPIRY_DAYS_MAX'] is not None and days_to_expiry > CONFIG['EXPIRY_DAYS_MAX']:
                continue
            try:
                calls = stock.option_chain(exp).calls
                if calls.empty:
                    continue
                calls['expirationDate'] = exp
                calls['type'] = 'call'
                T = days_to_expiry / 365.0
                if T <= 0:
                    continue
                S = current_price
                strikes = calls['strike'].values
                ivs = np.where(calls['impliedVolatility'].values > 0, calls['impliedVolatility'].values, 0.3)
                d1 = (np.log(S / strikes) + (CONFIG['RISK_FREE_RATE'] - CONFIG['DIVIDEND_YIELD'] + 0.5 * ivs**2) * T) / (ivs * np.sqrt(T))
                calls['delta'] = norm.cdf(d1)
                calls['gamma'] = norm.pdf(d1) / (S * ivs * np.sqrt(T))
                calls['theta'] = -(S * norm.pdf(d1) * ivs) / (2 * np.sqrt(T))
                calls['vega'] = S * norm.pdf(d1) * np.sqrt(T)
                option_data.append(calls)
            except Exception as e:
                logging.warning(f"Error fetching options for {symbol} expiry {exp}: {str(e)}")
                continue
        if option_data:
            options_df = pd.concat(option_data, ignore_index=True)
        return {'symbol': symbol, 'price': current_price, 'target_price': target_price, 'earnings_date': earnings_date, 'options': options_df}
    except Exception as e:
        FILTER_FAILURES['api_error'] += 1
        logging.error(f"Error fetching Yahoo Finance data for {symbol}: {str(e)}")
        return None

# ------------------------------
# Screen a single ticker
# ------------------------------
def screen_ticker(symbol):
    tv = get_tv_rating(symbol)
    if CONFIG['REQUIRE_TV_BUY'] and tv['rating'] not in ['BUY', 'STRONG_BUY']:
        FILTER_FAILURES['tv_rating'] += 1
        logging.info(f"Skipping {symbol}: TV rating {tv['rating']} not BUY/STRONG_BUY")
        return None
    yfdata = get_yf_data(symbol)
    if yfdata is None:
        return None
    # Filter options
    if not yfdata['options'].empty:
        valid_options = yfdata['options'][
            (yfdata['options']['volume'].fillna(0) >= CONFIG['MIN_OPTION_VOLUME']) &
            (yfdata['options']['openInterest'].fillna(0) >= CONFIG['MIN_OPTION_OPEN_INTEREST']) &
            (yfdata['options']['delta'].between(CONFIG['MIN_DELTA'], CONFIG['MAX_DELTA'])) &
            (yfdata['options']['lastPrice'] <= ((CONFIG['MAX_PREMIUM_PER_CONTRACT'] or float('inf')) / 100))
        ]

        if valid_options.empty:
            logging.info(f"Using default option values for {symbol} (no valid options)")
            cop = 50
            iv_score = 0.3
            delta_score = 0.5
            strike = yfdata['price']
            premium = 0
            expiration = None
        else:
            top_call = valid_options.sort_values(by='delta', ascending=False).iloc[0]
            cop = top_call['delta'] * 100
            iv_score = min(top_call['impliedVolatility'] / 0.5, 1.0)
            delta_score = min(max(top_call['delta'], 0), 1)
            strike = top_call['strike']
            premium = top_call['lastPrice']
            expiration = top_call['expirationDate']
    else:
        logging.info(f"Using default option values for {symbol} (no options data)")
        cop = 50
        iv_score = 0.3
        delta_score = 0.5
        strike = yfdata['price']
        premium = 0
        expiration = None
    # Upside
    upside = (yfdata['target_price'] / yfdata['price']) if yfdata['target_price'] else 1.0
    upside_score = min(max((upside - 1) / 1.0, 0), 1)
    # Score
    score = (CONFIG['SCORE_WEIGHTS']['tv'] * tv['score'] +
             CONFIG['SCORE_WEIGHTS']['upside'] * upside_score +
             CONFIG['SCORE_WEIGHTS']['delta'] * delta_score +
             CONFIG['SCORE_WEIGHTS']['iv'] * iv_score)
    return {
        'symbol': yfdata['symbol'],
        'price': yfdata['price'],
        'cost_100_shares': yfdata['price'] * 100,
        'target_price': yfdata['target_price'],
        'earnings_date': yfdata['earnings_date'],
        'tv_rating': tv['rating'],
        'score': score,
        'chance_of_profit': cop,
        'iv': iv_score,
        'delta': delta_score,
        'strike': strike,
        'expiration_date': expiration,
        'premium': premium
    }

# ------------------------------
# Run the screener for a batch of tickers
# ------------------------------
def run_screener_from_csv_batch(tickers):
    results = []
    with ThreadPoolExecutor(max_workers=CONFIG['MAX_WORKERS']) as executor:
        futures = {executor.submit(screen_ticker, t): t for t in tickers}
        for f in tqdm(as_completed(futures), total=len(futures), desc="Screening batch"):
            r = f.result()
            if r:
                results.append(r)
    return pd.DataFrame(results)

# ------------------------------
# Run the screener with batch processing
# ------------------------------
@timed
def run_screener_from_csv(csv_file='all_stocks.csv', batch_size=500):
    try:
        df = pd.read_csv(csv_file)
        if 'Symbol' not in df.columns:
            raise ValueError("CSV file must contain a 'Symbol' column")
        tickers = df['Symbol'].tolist()
    except FileNotFoundError:
        logging.error(f"CSV file {csv_file} not found")
        return pd.DataFrame()
    except pd.errors.EmptyDataError:
        logging.error(f"CSV file {csv_file} is empty")
        return pd.DataFrame()
    logging.info(f"Processing {len(tickers)} tickers in batches of {batch_size}")
    results = []
    for i in range(0, len(tickers), batch_size):
        batch = tickers[i:i+batch_size]
        logging.info(f"Processing batch {i//batch_size + 1}: {len(batch)} tickers")
        df_batch = run_screener_from_csv_batch(batch)
        if not df_batch.empty:
            results.append(df_batch)
    if not results:
        print("No stocks passed the screening")
        print("\nFilter Failure Counts:")
        print(json.dumps(FILTER_FAILURES, indent=2))
        return pd.DataFrame()
    df_results = pd.concat(results).sort_values(by='score', ascending=False).head(CONFIG['TOP_N'])
    # Save results
    date_str = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M")
    output_file = f"us_stock_options_screened_{date_str}.csv"

    df_results.to_csv(output_file, index=False)
    print(f"Results saved to {output_file}")
    # Print summary
    if not df_results.empty:
        print("\nTop 5 Stocks by Score:")
        print(df_results[['symbol', 'price', 'cost_100_shares', 'tv_rating', 'score', 'chance_of_profit']].head())
        # Plot top 10 stocks
        if len(df_results) >= 5:
            top_10 = df_results.head(10)
            plt.figure(figsize=(10, 6))
            plt.bar(top_10['symbol'], top_10['score'], color='green', edgecolor='darkgreen')
            plt.title('Top 10 Stocks by Score')
            plt.xlabel('Symbol')
            plt.ylabel('Score')
            plt.xticks(rotation=45)
            plt.tight_layout()
            plt.show()
    return df_results

# ------------------------------
# Manual stock check
# ------------------------------
def check_stock(symbol):
    result = screen_ticker(symbol)
    if result:
        df = pd.DataFrame([result])
        print(df[['symbol', 'price', 'cost_100_shares', 'tv_rating', 'score', 'chance_of_profit']])
    else:
        print(f"{symbol} did not pass basic filters (price/earnings/TV/market_cap)")

# ------------------------------
# Test calculations
# ------------------------------
def test_calculations():
    symbol = 'AAPL'
    data = get_yf_data(symbol)
    if data and not data['options'].empty:
        top_call = data['options'].iloc[0]
        assert 0 <= top_call['delta'] <= 1, f"Delta out of range for {symbol}"
        logging.info(f"Test passed for {symbol}: Delta={top_call['delta']:.2f}")

def check_single_stock(ticker, config):
    import yfinance as yf
    
    print(f"\n🔎 Checking {ticker} ...")
    stock = yf.Ticker(ticker)

    try:
        expiry = stock.options[0]  # first expiry
        opt_chain = stock.option_chain(expiry)
        options = opt_chain.calls  # you can also check puts
        options["type"] = "call"
    except Exception as e:
        print(f"❌ Could not fetch options for {ticker}: {e}")
        return

    results = []
    for _, row in options.iterrows():
        score = 0
        notes = []

        # Volume filter
        if row["volume"] >= config["MIN_OPTION_VOLUME"]:
            notes.append("✅ Volume OK")
            score += 1
        else:
            notes.append("❌ Volume Low")

        # Open Interest filter
        if row["openInterest"] >= config["MIN_OPTION_OPEN_INTEREST"]:
            notes.append("✅ OI OK")
            score += 1
        else:
            notes.append("❌ OI Low")

        # Delta filter (if available)
        if "delta" in row and row["delta"] is not None:
            if config["MIN_DELTA"] <= row["delta"] <= config["MAX_DELTA"]:
                notes.append("✅ Delta OK")
                score += 1
            else:
                notes.append("❌ Delta Out of Range")
        else:
            notes.append("⚠️ Delta Not Available")

        # Premium filter
        premium_limit = (config["MAX_PREMIUM_PER_CONTRACT"] or float("inf")) / 100
        if row["lastPrice"] <= premium_limit:
            notes.append("✅ Premium OK")
            score += 1
        else:
            notes.append("❌ Premium High")

        results.append({
            "strike": row["strike"],
            "lastPrice": row["lastPrice"],
            "score": score,
            "notes": "; ".join(notes)
        })

    return results
# ------------------------------
# Example usage
# ----------------------
if __name__ == "__main__":
    test_calculations()
    # df_all = run_screener_from_csv('all_stocks.csv', batch_size=500)
    # check_stock('AAPL')
    run_screener_from_csv()
# Out:
# 2025-08-19 20:44:26,029 - ERROR - Error fetching Yahoo Finance data for AAPL: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:44:26,035 - INFO - Processing 517 tickers in batches of 500
# 2025-08-19 20:44:26,036 - INFO - Processing batch 1: 500 tickers
# Screening batch:   0%|                                                                         | 0/500 [00:00<?, ?it/s]2025-08-19 20:44:26,277 - WARNING - Failed to get TradingView rating for ABT: Exchange or symbol not found.
# 2025-08-19 20:44:26,366 - WARNING - Failed to get TradingView rating for ABBV: Exchange or symbol not found.
# 2025-08-19 20:44:26,369 - WARNING - Failed to get TradingView rating for ACN: Exchange or symbol not found.
# 2025-08-19 20:44:26,369 - WARNING - Failed to get TradingView rating for AOS: Exchange or symbol not found.
# 2025-08-19 20:44:26,370 - WARNING - Failed to get TradingView rating for AES: Exchange or symbol not found.
# 2025-08-19 20:44:26,371 - WARNING - Failed to get TradingView rating for MMM: Exchange or symbol not found.
# 2025-08-19 20:44:26,371 - WARNING - Failed to get TradingView rating for ADBE: 'RECOMMEND'
# 2025-08-19 20:44:26,371 - WARNING - Failed to get TradingView rating for AMD: 'RECOMMEND'
# 2025-08-19 20:44:26,800 - ERROR - Error fetching Yahoo Finance data for ADBE: Too Many Requests. Rate limited. Try after a while.
# Screening batch:   0%|▏                                                                | 1/500 [00:00<06:56,  1.20it/s]2025-08-19 20:44:26,956 - WARNING - Failed to get TradingView rating for AFL: Exchange or symbol not found.
# 2025-08-19 20:44:27,226 - ERROR - Error fetching Yahoo Finance data for AFL: Too Many Requests. Rate limited. Try after a while.
# Screening batch:   0%|▎                                                                | 2/500 [00:01<04:26,  1.87it/s]2025-08-19 20:44:27,352 - WARNING - Failed to get TradingView rating for A: Exchange or symbol not found.
# 2025-08-19 20:44:27,506 - ERROR - Error fetching Yahoo Finance data for A: Too Many Requests. Rate limited. Try after a while.
# Screening batch:   1%|▍                                                                | 3/500 [00:01<03:27,  2.40it/s]2025-08-19 20:44:27,604 - WARNING - Failed to get TradingView rating for APD: Exchange or symbol not found.
# 2025-08-19 20:44:27,642 - WARNING - Failed to get TradingView rating for ABNB: 'RECOMMEND'
# 2025-08-19 20:44:27,780 - ERROR - Error fetching Yahoo Finance data for APD: Too Many Requests. Rate limited. Try after a while.
# Screening batch:   1%|▋                                                                | 5/500 [00:01<02:08,  3.85it/s]2025-08-19 20:44:27,889 - WARNING - Failed to get TradingView rating for AKAM: 'RECOMMEND'
# 2025-08-19 20:44:28,030 - ERROR - Error fetching Yahoo Finance data for AKAM: Too Many Requests. Rate limited. Try after a while.
# Screening batch:   1%|▊                                                                | 6/500 [00:01<02:06,  3.89it/s]2025-08-19 20:44:28,128 - WARNING - Failed to get TradingView rating for ALB: Exchange or symbol not found.
# Screening batch:   1%|▉                                                                | 7/500 [00:02<02:11,  3.74it/s]2025-08-19 20:44:28,415 - ERROR - Error fetching Yahoo Finance data for ALB: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:44:28,433 - WARNING - Failed to get TradingView rating for ARE: Exchange or symbol not found.
# Screening batch:   2%|█▏                                                               | 9/500 [00:02<01:26,  5.68it/s]2025-08-19 20:44:28,503 - WARNING - Failed to get TradingView rating for ALGN: 'RECOMMEND'
# 2025-08-19 20:44:28,569 - WARNING - Failed to get TradingView rating for ALLE: Exchange or symbol not found.
# 2025-08-19 20:44:28,650 - WARNING - Failed to get TradingView rating for LNT: 'RECOMMEND'
# Screening batch:   2%|█▍                                                              | 11/500 [00:02<01:14,  6.59it/s]2025-08-19 20:44:28,710 - ERROR - Error fetching Yahoo Finance data for ALGN: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:44:28,752 - WARNING - Failed to get TradingView rating for ALL: Exchange or symbol not found.
# Screening batch:   3%|█▊                                                              | 14/500 [00:02<00:48, 10.09it/s]2025-08-19 20:44:28,799 - WARNING - Failed to get TradingView rating for GOOGL: 'RECOMMEND'
# 2025-08-19 20:44:28,848 - WARNING - Failed to get TradingView rating for MO: Exchange or symbol not found.
# 2025-08-19 20:44:28,861 - WARNING - Failed to get TradingView rating for GOOG: 'RECOMMEND'
# 2025-08-19 20:44:29,004 - ERROR - Error fetching Yahoo Finance data for GOOGL: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:44:29,087 - WARNING - Failed to get TradingView rating for AMZN: 'RECOMMEND'
# 2025-08-19 20:44:29,300 - ERROR - Error fetching Yahoo Finance data for AMZN: Too Many Requests. Rate limited. Try after a while.
# Screening batch:   3%|██                                                              | 16/500 [00:03<01:10,  6.87it/s]2025-08-19 20:44:29,470 - WARNING - Failed to get TradingView rating for AMCR: Exchange or symbol not found.
# 2025-08-19 20:44:29,494 - WARNING - Failed to get TradingView rating for AEE: Exchange or symbol not found.
# Screening batch:   4%|██▍                                                             | 19/500 [00:03<01:20,  6.01it/s]2025-08-19 20:44:30,034 - ERROR - Error fetching Yahoo Finance data for AMCR: Too Many Requests. Rate limited. Try after a while.
# Screening batch:   4%|██▋                                                             | 21/500 [00:03<01:06,  7.15it/s]2025-08-19 20:44:30,175 - WARNING - Failed to get TradingView rating for AEP: 'RECOMMEND'
# 2025-08-19 20:44:30,222 - WARNING - Failed to get TradingView rating for AIG: Exchange or symbol not found.
# 2025-08-19 20:44:30,251 - WARNING - Failed to get TradingView rating for AXP: Exchange or symbol not found.
# 2025-08-19 20:44:30,265 - WARNING - Failed to get TradingView rating for AMT: Exchange or symbol not found.
# 2025-08-19 20:44:30,393 - ERROR - Error fetching Yahoo Finance data for AMT: Too Many Requests. Rate limited. Try after a while.
# Screening batch:   4%|██▊                                                             | 22/500 [00:04<01:26,  5.50it/s]2025-08-19 20:44:30,460 - WARNING - Failed to get TradingView rating for AWK: Exchange or symbol not found.
# 2025-08-19 20:44:30,554 - WARNING - Failed to get TradingView rating for AMP: Exchange or symbol not found.
# 2025-08-19 20:44:30,724 - ERROR - Error fetching Yahoo Finance data for AWK: Too Many Requests. Rate limited. Try after a while.
# Screening batch:   5%|███                                                             | 24/500 [00:04<01:24,  5.67it/s]2025-08-19 20:44:30,804 - WARNING - Failed to get TradingView rating for AME: Exchange or symbol not found.
# 2025-08-19 20:44:30,993 - ERROR - Error fetching Yahoo Finance data for AME: Too Many Requests. Rate limited. Try after a while.
# Screening batch:   5%|███▏                                                            | 25/500 [00:04<01:32,  5.13it/s]2025-08-19 20:44:31,088 - WARNING - Failed to get TradingView rating for AMGN: 'RECOMMEND'
# Screening batch:   5%|███▎                                                            | 26/500 [00:05<01:33,  5.05it/s]2025-08-19 20:44:31,260 - ERROR - Error fetching Yahoo Finance data for AMGN: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:44:31,285 - WARNING - Failed to get TradingView rating for APH: Exchange or symbol not found.
# 2025-08-19 20:44:31,348 - WARNING - Failed to get TradingView rating for ADI: 'RECOMMEND'
# 2025-08-19 20:44:31,377 - WARNING - Failed to get TradingView rating for AON: Exchange or symbol not found.
# Screening batch:   6%|███▋                                                            | 29/500 [00:05<01:09,  6.77it/s]2025-08-19 20:44:31,533 - ERROR - Error fetching Yahoo Finance data for ADI: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:44:31,589 - WARNING - Failed to get TradingView rating for APO: Exchange or symbol not found.
# Screening batch:   6%|████                                                            | 32/500 [00:05<00:47,  9.88it/s]2025-08-19 20:44:31,606 - WARNING - Failed to get TradingView rating for APA: 'RECOMMEND'
# 2025-08-19 20:44:31,631 - WARNING - Failed to get TradingView rating for AAPL: 'RECOMMEND'
# 2025-08-19 20:44:31,679 - WARNING - Failed to get TradingView rating for AMAT: 'RECOMMEND'
# 2025-08-19 20:44:31,852 - ERROR - Error fetching Yahoo Finance data for AAPL: Too Many Requests. Rate limited. Try after a while.
# Screening batch:   7%|████▎                                                           | 34/500 [00:05<00:54,  8.59it/s]2025-08-19 20:44:31,958 - WARNING - Failed to get TradingView rating for APTV: Exchange or symbol not found.
# 2025-08-19 20:44:31,989 - WARNING - Failed to get TradingView rating for ACGL: 'RECOMMEND'
# 2025-08-19 20:44:32,096 - ERROR - Error fetching Yahoo Finance data for APTV: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:44:32,182 - WARNING - Failed to get TradingView rating for ADM: Exchange or symbol not found.
# Screening batch:   7%|████▌                                                           | 36/500 [00:06<00:57,  8.11it/s]2025-08-19 20:44:32,237 - WARNING - Failed to get TradingView rating for ANET: Exchange or symbol not found.
# 2025-08-19 20:44:32,387 - WARNING - Failed to get TradingView rating for AJG: Exchange or symbol not found.
# 2025-08-19 20:44:32,390 - ERROR - Error fetching Yahoo Finance data for ADM: Too Many Requests. Rate limited. Try after a while.
# Screening batch:   8%|████▊                                                           | 38/500 [00:06<00:54,  8.52it/s]2025-08-19 20:44:32,455 - WARNING - Failed to get TradingView rating for AIZ: Exchange or symbol not found.
# 2025-08-19 20:44:32,649 - ERROR - Error fetching Yahoo Finance data for AIZ: Too Many Requests. Rate limited. Try after a while.
# Screening batch:   8%|█████                                                           | 40/500 [00:06<00:55,  8.26it/s]2025-08-19 20:44:32,695 - WARNING - Failed to get TradingView rating for T: Exchange or symbol not found.
# 2025-08-19 20:44:32,729 - WARNING - Failed to get TradingView rating for ATO: Exchange or symbol not found.
# 2025-08-19 20:44:32,934 - ERROR - Error fetching Yahoo Finance data for ATO: Too Many Requests. Rate limited. Try after a while.
# Screening batch:   8%|█████▏                                                          | 41/500 [00:06<01:09,  6.63it/s]2025-08-19 20:44:33,003 - WARNING - Failed to get TradingView rating for ADSK: 'RECOMMEND'
# 2025-08-19 20:44:33,265 - ERROR - Error fetching Yahoo Finance data for ADSK: Too Many Requests. Rate limited. Try after a while.
# Screening batch:   8%|█████▍                                                          | 42/500 [00:07<01:24,  5.41it/s]2025-08-19 20:44:33,351 - WARNING - Failed to get TradingView rating for ADP: 'RECOMMEND'
# 2025-08-19 20:44:33,418 - WARNING - Failed to get TradingView rating for AZO: Exchange or symbol not found.
# Screening batch:   9%|█████▋                                                          | 44/500 [00:07<01:11,  6.33it/s]2025-08-19 20:44:33,564 - ERROR - Error fetching Yahoo Finance data for ADP: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:44:33,570 - WARNING - Failed to get TradingView rating for AVB: Exchange or symbol not found.
# 2025-08-19 20:44:33,578 - WARNING - Failed to get TradingView rating for AVY: Exchange or symbol not found.
# 2025-08-19 20:44:33,622 - WARNING - Failed to get TradingView rating for BKR: 'RECOMMEND'
# 2025-08-19 20:44:33,627 - WARNING - Failed to get TradingView rating for AXON: 'RECOMMEND'
# 2025-08-19 20:44:33,906 - ERROR - Error fetching Yahoo Finance data for BKR: Too Many Requests. Rate limited. Try after a while.
# Screening batch:  10%|██████▏                                                         | 48/500 [00:07<00:59,  7.62it/s]2025-08-19 20:44:33,995 - WARNING - Failed to get TradingView rating for BALL: Exchange or symbol not found.
# 2025-08-19 20:44:34,006 - WARNING - Failed to get TradingView rating for BAC: Exchange or symbol not found.
# 2025-08-19 20:44:34,169 - ERROR - Error fetching Yahoo Finance data for BALL: Too Many Requests. Rate limited. Try after a while.
# Screening batch:  10%|██████▍                                                         | 50/500 [00:08<00:58,  7.63it/s]2025-08-19 20:44:34,254 - WARNING - Failed to get TradingView rating for BAX: Exchange or symbol not found.
# Screening batch:  10%|██████▌                                                         | 51/500 [00:08<01:06,  6.75it/s]2025-08-19 20:44:34,427 - ERROR - Error fetching Yahoo Finance data for BAX: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:44:34,504 - WARNING - Failed to get TradingView rating for BDX: Exchange or symbol not found.
# 2025-08-19 20:44:34,504 - WARNING - Failed to get TradingView rating for BRK.B: Exchange or symbol not found.
# 2025-08-19 20:44:34,514 - WARNING - Failed to get TradingView rating for BBY: Exchange or symbol not found.
# 2025-08-19 20:44:34,592 - WARNING - Failed to get TradingView rating for TECH: 'RECOMMEND'
# Screening batch:  11%|███████                                                         | 55/500 [00:08<00:46,  9.67it/s]2025-08-19 20:44:34,681 - WARNING - Failed to get TradingView rating for BIIB: 'RECOMMEND'
# 2025-08-19 20:44:34,691 - ERROR - Error fetching Yahoo Finance data for BBY: Too Many Requests. Rate limited. Try after a while.
# Screening batch:  11%|███████▎                                                        | 57/500 [00:08<00:41, 10.66it/s]2025-08-19 20:44:34,813 - WARNING - Failed to get TradingView rating for BX: Exchange or symbol not found.
# 2025-08-19 20:44:34,837 - WARNING - Failed to get TradingView rating for BLK: Exchange or symbol not found.
# 2025-08-19 20:44:34,971 - ERROR - Error fetching Yahoo Finance data for BLK: Too Many Requests. Rate limited. Try after a while.
# Screening batch:  12%|███████▌                                                        | 59/500 [00:08<00:43, 10.24it/s]2025-08-19 20:44:34,978 - INFO - Skipping BRK.B: Invalid price
# 2025-08-19 20:44:35,032 - WARNING - Failed to get TradingView rating for BA: Exchange or symbol not found.
# 2025-08-19 20:44:35,037 - WARNING - Failed to get TradingView rating for XYZ: Exchange or symbol not found.
# 2025-08-19 20:44:35,057 - WARNING - Failed to get TradingView rating for BK: Exchange or symbol not found.
# 2025-08-19 20:44:35,223 - ERROR - Error fetching Yahoo Finance data for BK: Too Many Requests. Rate limited. Try after a while.
# Screening batch:  12%|███████▊                                                        | 61/500 [00:09<00:46,  9.49it/s]2025-08-19 20:44:35,304 - WARNING - Failed to get TradingView rating for BKNG: 'RECOMMEND'
# 2025-08-19 20:44:35,501 - ERROR - Error fetching Yahoo Finance data for BKNG: Too Many Requests. Rate limited. Try after a while.
# Screening batch:  13%|████████                                                        | 63/500 [00:09<00:51,  8.48it/s]2025-08-19 20:44:35,564 - WARNING - Failed to get TradingView rating for BSX: Exchange or symbol not found.
# 2025-08-19 20:44:35,605 - WARNING - Failed to get TradingView rating for BMY: Exchange or symbol not found.
# 2025-08-19 20:44:35,617 - WARNING - Failed to get TradingView rating for AVGO: 'RECOMMEND'
# 2025-08-19 20:44:35,783 - ERROR - Error fetching Yahoo Finance data for BSX: Too Many Requests. Rate limited. Try after a while.
# Screening batch:  13%|████████▎                                                       | 65/500 [00:09<00:52,  8.24it/s]2025-08-19 20:44:35,856 - WARNING - Failed to get TradingView rating for BR: Exchange or symbol not found.
# Screening batch:  13%|████████▍                                                       | 66/500 [00:09<01:02,  6.89it/s]2025-08-19 20:44:36,049 - ERROR - Error fetching Yahoo Finance data for BR: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:44:36,102 - WARNING - Failed to get TradingView rating for BRO: Exchange or symbol not found.
# 2025-08-19 20:44:36,106 - WARNING - Failed to get TradingView rating for BF.B: Exchange or symbol not found.
# 2025-08-19 20:44:36,305 - ERROR - Error fetching Yahoo Finance data for BF.B: Too Many Requests. Rate limited. Try after a while.
# Screening batch:  14%|████████▋                                                       | 68/500 [00:10<01:00,  7.12it/s]2025-08-19 20:44:36,380 - WARNING - Failed to get TradingView rating for BLDR: Exchange or symbol not found.
# 2025-08-19 20:44:36,593 - ERROR - Error fetching Yahoo Finance data for BLDR: Too Many Requests. Rate limited. Try after a while.
# Screening batch:  14%|████████▊                                                       | 69/500 [00:10<01:12,  5.93it/s]2025-08-19 20:44:36,685 - WARNING - Failed to get TradingView rating for BG: Exchange or symbol not found.
# 2025-08-19 20:44:36,878 - ERROR - Error fetching Yahoo Finance data for BG: Too Many Requests. Rate limited. Try after a while.
# Screening batch:  14%|████████▉                                                       | 70/500 [00:10<01:23,  5.18it/s]2025-08-19 20:44:36,934 - WARNING - Failed to get TradingView rating for BXP: Exchange or symbol not found.
# 2025-08-19 20:44:37,004 - WARNING - Failed to get TradingView rating for CDNS: 'RECOMMEND'
# 2025-08-19 20:44:37,004 - WARNING - Failed to get TradingView rating for CHRW: 'RECOMMEND'
# 2025-08-19 20:44:37,030 - WARNING - Failed to get TradingView rating for CZR: 'RECOMMEND'
# Screening batch:  15%|█████████▍                                                      | 74/500 [00:11<00:51,  8.20it/s]2025-08-19 20:44:37,172 - ERROR - Error fetching Yahoo Finance data for BXP: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:44:37,204 - WARNING - Failed to get TradingView rating for CPT: Exchange or symbol not found.
# 2025-08-19 20:44:37,236 - WARNING - Failed to get TradingView rating for CPB: 'RECOMMEND'
# 2025-08-19 20:44:37,496 - ERROR - Error fetching Yahoo Finance data for CPB: Too Many Requests. Rate limited. Try after a while.
# Screening batch:  15%|█████████▋                                                      | 76/500 [00:11<00:58,  7.21it/s]2025-08-19 20:44:37,575 - WARNING - Failed to get TradingView rating for COF: Exchange or symbol not found.
# 2025-08-19 20:44:37,605 - WARNING - Failed to get TradingView rating for CAH: Exchange or symbol not found.
# 2025-08-19 20:44:37,789 - ERROR - Error fetching Yahoo Finance data for COF: Too Many Requests. Rate limited. Try after a while.
# Screening batch:  16%|█████████▉                                                      | 78/500 [00:11<00:59,  7.08it/s]2025-08-19 20:44:37,869 - WARNING - Failed to get TradingView rating for KMX: Exchange or symbol not found.
# Screening batch:  16%|██████████                                                      | 79/500 [00:11<01:05,  6.40it/s]2025-08-19 20:44:38,103 - ERROR - Error fetching Yahoo Finance data for KMX: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:44:38,103 - WARNING - Failed to get TradingView rating for CCL: Exchange or symbol not found.
# Screening batch:  16%|██████████▍                                                     | 82/500 [00:12<00:43,  9.56it/s]2025-08-19 20:44:38,169 - WARNING - Failed to get TradingView rating for CAT: Exchange or symbol not found.
# 2025-08-19 20:44:38,169 - WARNING - Failed to get TradingView rating for CARR: Exchange or symbol not found.
# 2025-08-19 20:44:38,182 - WARNING - Failed to get TradingView rating for CBOE: Exchange or symbol not found.
# 2025-08-19 20:44:38,576 - WARNING - Failed to get TradingView rating for CBRE: Exchange or symbol not found.
# Screening batch:  17%|██████████▊                                                     | 84/500 [00:12<01:00,  6.86it/s]2025-08-19 20:44:38,706 - WARNING - Failed to get TradingView rating for CDW: 'RECOMMEND'
# 2025-08-19 20:44:39,196 - WARNING - Failed to get TradingView rating for COR: Exchange or symbol not found.
# Screening batch:  17%|███████████                                                     | 86/500 [00:13<01:20,  5.15it/s]2025-08-19 20:44:39,348 - WARNING - Failed to get TradingView rating for CNC: Exchange or symbol not found.
# Screening batch:  18%|███████████▎                                                    | 88/500 [00:13<01:02,  6.54it/s]2025-08-19 20:44:39,441 - WARNING - Failed to get TradingView rating for CNP: Exchange or symbol not found.
# Screening batch:  18%|███████████▊                                                    | 92/500 [00:13<00:38, 10.53it/s]2025-08-19 20:44:40,009 - WARNING - Failed to get TradingView rating for CF: Exchange or symbol not found.
# 2025-08-19 20:44:40,095 - WARNING - Failed to get TradingView rating for CRL: Exchange or symbol not found.
# 2025-08-19 20:44:40,205 - WARNING - Failed to get TradingView rating for SCHW: Exchange or symbol not found.
# 2025-08-19 20:44:40,274 - WARNING - Failed to get TradingView rating for CHTR: 'RECOMMEND'
# 2025-08-19 20:44:40,318 - WARNING - Failed to get TradingView rating for CVX: Exchange or symbol not found.
# 2025-08-19 20:44:40,726 - WARNING - Failed to get TradingView rating for CMG: Exchange or symbol not found.
# Screening batch:  19%|████████████                                                    | 94/500 [00:14<01:37,  4.17it/s]2025-08-19 20:44:40,891 - WARNING - Failed to get TradingView rating for CB: Exchange or symbol not found.
# 2025-08-19 20:44:41,027 - WARNING - Failed to get TradingView rating for CHD: Exchange or symbol not found.
# Screening batch:  19%|████████████▎                                                   | 96/500 [00:15<01:40,  4.01it/s]2025-08-19 20:44:41,456 - WARNING - Failed to get TradingView rating for CI: Exchange or symbol not found.
# 2025-08-19 20:44:41,462 - WARNING - Failed to get TradingView rating for CINF: 'RECOMMEND'
# Screening batch:  20%|████████████▌                                                   | 98/500 [00:15<01:20,  4.97it/s]2025-08-19 20:44:41,606 - WARNING - Failed to get TradingView rating for CSCO: 'RECOMMEND'
# 2025-08-19 20:44:41,606 - WARNING - Failed to get TradingView rating for CTAS: 'RECOMMEND'
# Screening batch:  20%|████████████▌                                                  | 100/500 [00:15<01:04,  6.23it/s]2025-08-19 20:44:41,715 - WARNING - Failed to get TradingView rating for C: Exchange or symbol not found.
# 2025-08-19 20:44:41,743 - WARNING - Failed to get TradingView rating for CFG: Exchange or symbol not found.
# 2025-08-19 20:44:41,780 - WARNING - Failed to get TradingView rating for CLX: Exchange or symbol not found.
# Screening batch:  21%|████████████▉                                                  | 103/500 [00:15<00:55,  7.13it/s]2025-08-19 20:44:42,030 - WARNING - Failed to get TradingView rating for CME: 'RECOMMEND'
# 2025-08-19 20:44:42,196 - WARNING - Failed to get TradingView rating for CMS: Exchange or symbol not found.
# Screening batch:  21%|█████████████▏                                                 | 105/500 [00:16<01:00,  6.48it/s]2025-08-19 20:44:42,420 - WARNING - Failed to get TradingView rating for KO: Exchange or symbol not found.
# 2025-08-19 20:44:42,426 - WARNING - Failed to get TradingView rating for CTSH: 'RECOMMEND'
# Screening batch:  21%|█████████████▍                                                 | 107/500 [00:16<01:01,  6.37it/s]2025-08-19 20:44:42,743 - WARNING - Failed to get TradingView rating for COIN: 'RECOMMEND'
# Screening batch:  22%|█████████████▌                                                 | 108/500 [00:16<00:58,  6.71it/s]2025-08-19 20:44:42,832 - WARNING - Failed to get TradingView rating for CL: Exchange or symbol not found.
# 2025-08-19 20:44:42,857 - WARNING - Failed to get TradingView rating for CMCSA: 'RECOMMEND'
# 2025-08-19 20:44:42,924 - WARNING - Failed to get TradingView rating for CAG: Exchange or symbol not found.
# 2025-08-19 20:44:42,950 - WARNING - Failed to get TradingView rating for COP: Exchange or symbol not found.
# Screening batch:  22%|██████████████                                                 | 112/500 [00:16<00:39,  9.70it/s]2025-08-19 20:44:43,131 - WARNING - Failed to get TradingView rating for ED: Exchange or symbol not found.
# 2025-08-19 20:44:43,136 - WARNING - Failed to get TradingView rating for STZ: Exchange or symbol not found.
# Screening batch:  23%|██████████████▎                                                | 114/500 [00:17<00:57,  6.76it/s]2025-08-19 20:44:43,614 - WARNING - Failed to get TradingView rating for CEG: 'RECOMMEND'
# Screening batch:  23%|██████████████▍                                                | 115/500 [00:17<01:05,  5.89it/s]2025-08-19 20:44:43,893 - WARNING - Failed to get TradingView rating for COO: 'RECOMMEND'
# Screening batch:  23%|██████████████▋                                                | 117/500 [00:17<00:52,  7.32it/s]2025-08-19 20:44:44,003 - WARNING - Failed to get TradingView rating for CPRT: 'RECOMMEND'
# 2025-08-19 20:44:44,039 - WARNING - Failed to get TradingView rating for GLW: Exchange or symbol not found.
# 2025-08-19 20:44:44,073 - WARNING - Failed to get TradingView rating for CPAY: Exchange or symbol not found.
# Screening batch:  24%|██████████████▉                                                | 119/500 [00:18<00:46,  8.28it/s]2025-08-19 20:44:44,188 - WARNING - Failed to get TradingView rating for CTVA: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:44,232 - WARNING - Failed to get TradingView rating for CSGP: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  24%|███████████████▏                                               | 121/500 [00:18<00:44,  8.55it/s]2025-08-19 20:44:44,397 - WARNING - Failed to get TradingView rating for COST: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:44,561 - WARNING - Failed to get TradingView rating for CTRA: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  25%|███████████████▍                                               | 123/500 [00:18<00:50,  7.45it/s]2025-08-19 20:44:44,747 - WARNING - Failed to get TradingView rating for CRWD: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:44,773 - WARNING - Failed to get TradingView rating for CCI: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  25%|███████████████▊                                               | 125/500 [00:18<00:41,  9.00it/s]2025-08-19 20:44:44,868 - WARNING - Failed to get TradingView rating for CSX: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:44,893 - WARNING - Failed to get TradingView rating for CMI: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  25%|████████████████                                               | 127/500 [00:18<00:41,  8.96it/s]2025-08-19 20:44:45,093 - WARNING - Failed to get TradingView rating for CVS: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:45,161 - WARNING - Failed to get TradingView rating for DHR: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  26%|████████████████▎                                              | 129/500 [00:19<00:45,  8.11it/s]2025-08-19 20:44:45,385 - WARNING - Failed to get TradingView rating for DRI: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  26%|████████████████▍                                              | 130/500 [00:19<00:54,  6.78it/s]2025-08-19 20:44:45,663 - WARNING - Failed to get TradingView rating for DDOG: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:45,696 - WARNING - Failed to get TradingView rating for DVA: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  26%|████████████████▋                                              | 132/500 [00:19<00:44,  8.26it/s]2025-08-19 20:44:45,790 - WARNING - Failed to get TradingView rating for DAY: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  27%|████████████████▊                                              | 133/500 [00:19<00:58,  6.27it/s]2025-08-19 20:44:46,108 - WARNING - Failed to get TradingView rating for DECK: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  27%|████████████████▉                                              | 134/500 [00:20<00:53,  6.82it/s]2025-08-19 20:44:46,214 - WARNING - Failed to get TradingView rating for DE: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  27%|█████████████████                                              | 135/500 [00:20<00:53,  6.88it/s]2025-08-19 20:44:46,363 - WARNING - Failed to get TradingView rating for DELL: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:46,385 - WARNING - Failed to get TradingView rating for DAL: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  27%|█████████████████▎                                             | 137/500 [00:20<00:39,  9.10it/s]2025-08-19 20:44:46,476 - WARNING - Failed to get TradingView rating for DVN: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:46,485 - WARNING - Failed to get TradingView rating for DXCM: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:46,520 - WARNING - Failed to get TradingView rating for FANG: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  28%|█████████████████▋                                             | 140/500 [00:20<00:54,  6.60it/s]2025-08-19 20:44:47,080 - WARNING - Failed to get TradingView rating for DLR: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  28%|█████████████████▊                                             | 141/500 [00:21<01:08,  5.24it/s]2025-08-19 20:44:47,435 - WARNING - Failed to get TradingView rating for DG: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:47,493 - WARNING - Failed to get TradingView rating for DLTR: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  29%|██████████████████                                             | 143/500 [00:21<00:55,  6.41it/s]2025-08-19 20:44:47,634 - WARNING - Failed to get TradingView rating for DPZ: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:47,637 - WARNING - Failed to get TradingView rating for D: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:47,648 - WARNING - Failed to get TradingView rating for DASH: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:47,668 - WARNING - Failed to get TradingView rating for DOV: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  29%|██████████████████▌                                            | 147/500 [00:21<00:34, 10.29it/s]2025-08-19 20:44:47,759 - WARNING - Failed to get TradingView rating for DOW: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:48,252 - WARNING - Failed to get TradingView rating for DHI: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  30%|██████████████████▊                                            | 149/500 [00:22<00:51,  6.88it/s]2025-08-19 20:44:48,316 - WARNING - Failed to get TradingView rating for DTE: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:48,333 - WARNING - Failed to get TradingView rating for DUK: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:48,370 - WARNING - Failed to get TradingView rating for DD: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  30%|███████████████████▏                                           | 152/500 [00:22<00:46,  7.50it/s]2025-08-19 20:44:48,654 - WARNING - Failed to get TradingView rating for EMN: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:48,921 - WARNING - Failed to get TradingView rating for ETN: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  31%|███████████████████▍                                           | 154/500 [00:22<00:54,  6.39it/s]2025-08-19 20:44:49,107 - WARNING - Failed to get TradingView rating for EBAY: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:49,133 - WARNING - Failed to get TradingView rating for ECL: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:49,173 - WARNING - Failed to get TradingView rating for EIX: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:49,184 - WARNING - Failed to get TradingView rating for EW: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  32%|███████████████████▉                                           | 158/500 [00:23<00:39,  8.62it/s]2025-08-19 20:44:49,355 - WARNING - Failed to get TradingView rating for EA: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:49,404 - WARNING - Failed to get TradingView rating for ELV: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  32%|████████████████████▏                                          | 160/500 [00:23<00:39,  8.51it/s]2025-08-19 20:44:50,209 - WARNING - Failed to get TradingView rating for EMR: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:50,379 - WARNING - Failed to get TradingView rating for ENPH: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  32%|████████████████████▍                                          | 162/500 [00:24<01:07,  5.01it/s]2025-08-19 20:44:50,480 - WARNING - Failed to get TradingView rating for ETR: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  33%|████████████████████▌                                          | 163/500 [00:24<01:04,  5.20it/s]2025-08-19 20:44:50,639 - WARNING - Failed to get TradingView rating for EOG: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  33%|████████████████████▋                                          | 164/500 [00:24<01:00,  5.55it/s]2025-08-19 20:44:50,771 - WARNING - Failed to get TradingView rating for EPAM: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:50,841 - WARNING - Failed to get TradingView rating for EQT: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  33%|████████████████████▉                                          | 166/500 [00:24<00:56,  5.88it/s]2025-08-19 20:44:51,080 - WARNING - Failed to get TradingView rating for EFX: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  33%|█████████████████████                                          | 167/500 [00:25<00:52,  6.39it/s]2025-08-19 20:44:51,165 - WARNING - Failed to get TradingView rating for EQIX: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:51,222 - WARNING - Failed to get TradingView rating for EQR: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  34%|█████████████████████▎                                         | 169/500 [00:25<00:49,  6.65it/s]2025-08-19 20:44:51,441 - WARNING - Failed to get TradingView rating for ERIE: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  34%|█████████████████████▍                                         | 170/500 [00:25<00:49,  6.67it/s]2025-08-19 20:44:51,584 - WARNING - Failed to get TradingView rating for ESS: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:51,615 - WARNING - Failed to get TradingView rating for EL: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  34%|█████████████████████▋                                         | 172/500 [00:25<00:41,  8.00it/s]2025-08-19 20:44:51,755 - WARNING - Failed to get TradingView rating for EG: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:51,796 - WARNING - Failed to get TradingView rating for EVRG: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  35%|█████████████████████▉                                         | 174/500 [00:25<00:41,  7.93it/s]2025-08-19 20:44:52,009 - WARNING - Failed to get TradingView rating for ES: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:52,020 - WARNING - Failed to get TradingView rating for EXC: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  35%|██████████████████████▏                                        | 176/500 [00:26<00:34,  9.43it/s]2025-08-19 20:44:52,132 - WARNING - Failed to get TradingView rating for EXE: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  36%|██████████████████████▍                                        | 178/500 [00:26<00:29, 10.90it/s]2025-08-19 20:44:52,244 - WARNING - Failed to get TradingView rating for EXPE: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:52,273 - WARNING - Failed to get TradingView rating for EXPD: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:52,386 - WARNING - Failed to get TradingView rating for EXR: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  36%|██████████████████████▋                                        | 180/500 [00:26<00:30, 10.60it/s]2025-08-19 20:44:52,471 - WARNING - Failed to get TradingView rating for XOM: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  36%|██████████████████████▉                                        | 182/500 [00:26<00:29, 10.77it/s]2025-08-19 20:44:52,603 - WARNING - Failed to get TradingView rating for FFIV: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:52,643 - WARNING - Failed to get TradingView rating for FDS: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  37%|███████████████████████▏                                       | 184/500 [00:26<00:33,  9.29it/s]2025-08-19 20:44:52,902 - WARNING - Failed to get TradingView rating for FICO: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:52,930 - WARNING - Failed to get TradingView rating for FAST: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:52,956 - WARNING - Failed to get TradingView rating for FRT: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:53,010 - WARNING - Failed to get TradingView rating for FDX: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  37%|███████████████████████▌                                       | 187/500 [00:27<00:35,  8.91it/s]2025-08-19 20:44:53,278 - WARNING - Failed to get TradingView rating for FIS: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  38%|███████████████████████▋                                       | 188/500 [00:27<00:38,  8.11it/s]2025-08-19 20:44:53,458 - WARNING - Failed to get TradingView rating for FITB: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:53,504 - WARNING - Failed to get TradingView rating for FSLR: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  38%|███████████████████████▉                                       | 190/500 [00:27<00:32,  9.67it/s]2025-08-19 20:44:53,582 - WARNING - Failed to get TradingView rating for FE: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:53,643 - WARNING - Failed to get TradingView rating for FI: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  38%|████████████████████████▏                                      | 192/500 [00:27<00:35,  8.68it/s]2025-08-19 20:44:53,861 - WARNING - Failed to get TradingView rating for F: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:53,884 - WARNING - Failed to get TradingView rating for FTNT: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  39%|████████████████████████▍                                      | 194/500 [00:28<00:40,  7.52it/s]2025-08-19 20:44:54,205 - WARNING - Failed to get TradingView rating for FTV: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  39%|████████████████████████▌                                      | 195/500 [00:28<00:40,  7.61it/s]2025-08-19 20:44:54,346 - WARNING - Failed to get TradingView rating for FOXA: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:54,378 - WARNING - Failed to get TradingView rating for FOX: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  39%|████████████████████████▊                                      | 197/500 [00:28<00:45,  6.60it/s]2025-08-19 20:44:54,740 - WARNING - Failed to get TradingView rating for BEN: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:54,741 - WARNING - Failed to get TradingView rating for FCX: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  40%|█████████████████████████                                      | 199/500 [00:28<00:41,  7.22it/s]2025-08-19 20:44:54,934 - WARNING - Failed to get TradingView rating for GRMN: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  40%|█████████████████████████▎                                     | 201/500 [00:28<00:35,  8.50it/s]2025-08-19 20:44:55,039 - WARNING - Failed to get TradingView rating for IT: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:55,086 - WARNING - Failed to get TradingView rating for GE: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  40%|█████████████████████████▍                                     | 202/500 [00:29<00:38,  7.84it/s]2025-08-19 20:44:55,251 - WARNING - Failed to get TradingView rating for GEHC: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:55,295 - WARNING - Failed to get TradingView rating for GEV: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:55,328 - WARNING - Failed to get TradingView rating for GEN: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  41%|█████████████████████████▊                                     | 205/500 [00:29<00:27, 10.64it/s]2025-08-19 20:44:55,418 - WARNING - Failed to get TradingView rating for GNRC: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:55,653 - WARNING - Failed to get TradingView rating for GD: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  41%|██████████████████████████                                     | 207/500 [00:29<00:32,  8.97it/s]2025-08-19 20:44:55,721 - WARNING - Failed to get TradingView rating for GIS: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:44:56,067 - WARNING - Failed to get TradingView rating for GM: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  42%|██████████████████████████▎                                    | 209/500 [00:30<00:41,  7.09it/s]2025-08-19 20:44:56,141 - WARNING - Failed to get TradingView rating for GPC: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# ...
# 2025-08-19 20:45:01,563 - WARNING - Failed to get TradingView rating for PPG: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,575 - WARNING - Failed to get TradingView rating for PPL: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,577 - WARNING - Failed to get TradingView rating for PFG: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,580 - WARNING - Failed to get TradingView rating for PG: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,641 - ERROR - Error fetching Yahoo Finance data for PNW: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:01,642 - ERROR - Error fetching Yahoo Finance data for PSX: Too Many Requests. Rate limited. Try after a while.
# Screening batch:  74%|██████████████████████████████████████████████▊                | 372/500 [00:35<00:02, 47.94it/s]2025-08-19 20:45:01,649 - ERROR - Error fetching Yahoo Finance data for PNC: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:01,670 - ERROR - Error fetching Yahoo Finance data for POOL: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:01,695 - ERROR - Error fetching Yahoo Finance data for PPL: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:01,696 - ERROR - Error fetching Yahoo Finance data for PFG: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:01,696 - ERROR - Error fetching Yahoo Finance data for PPG: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:01,697 - WARNING - Failed to get TradingView rating for PLD: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,697 - WARNING - Failed to get TradingView rating for PGR: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,698 - WARNING - Failed to get TradingView rating for PRU: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,699 - ERROR - Error fetching Yahoo Finance data for PG: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:01,728 - WARNING - Failed to get TradingView rating for PEG: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,734 - ERROR - Error fetching Yahoo Finance data for PLD: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:01,744 - WARNING - Failed to get TradingView rating for PTC: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,751 - WARNING - Failed to get TradingView rating for PSA: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,752 - ERROR - Error fetching Yahoo Finance data for PGR: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:01,755 - ERROR - Error fetching Yahoo Finance data for PRU: Too Many Requests. Rate limited. Try after a while.
# Screening batch:  76%|████████████████████████████████████████████████               | 381/500 [00:35<00:02, 55.63it/s]2025-08-19 20:45:01,755 - WARNING - Failed to get TradingView rating for PWR: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,755 - WARNING - Failed to get TradingView rating for PHM: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,778 - ERROR - Error fetching Yahoo Finance data for PEG: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:01,786 - WARNING - Failed to get TradingView rating for QCOM: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,809 - ERROR - Error fetching Yahoo Finance data for PSA: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:01,826 - WARNING - Failed to get TradingView rating for RL: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,826 - WARNING - Failed to get TradingView rating for DGX: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,828 - ERROR - Error fetching Yahoo Finance data for PTC: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:01,831 - ERROR - Error fetching Yahoo Finance data for PWR: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:01,846 - WARNING - Failed to get TradingView rating for RJF: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,858 - ERROR - Error fetching Yahoo Finance data for QCOM: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:01,860 - WARNING - Failed to get TradingView rating for RTX: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,866 - ERROR - Error fetching Yahoo Finance data for PHM: Too Many Requests. Rate limited. Try after a while.
# Screening batch:  78%|████████████████████████████████████████████████▉              | 388/500 [00:35<00:01, 57.36it/s]2025-08-19 20:45:01,880 - ERROR - Error fetching Yahoo Finance data for RL: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:01,895 - WARNING - Failed to get TradingView rating for O: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,895 - WARNING - Failed to get TradingView rating for REG: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,900 - ERROR - Error fetching Yahoo Finance data for RJF: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:01,902 - ERROR - Error fetching Yahoo Finance data for DGX: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:01,916 - WARNING - Failed to get TradingView rating for REGN: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,918 - WARNING - Failed to get TradingView rating for RF: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,934 - WARNING - Failed to get TradingView rating for RSG: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,955 - WARNING - Failed to get TradingView rating for RMD: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:01,963 - WARNING - Failed to get TradingView rating for RVTY: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,006 - ERROR - Error fetching Yahoo Finance data for RTX: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,008 - ERROR - Error fetching Yahoo Finance data for O: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,009 - ERROR - Error fetching Yahoo Finance data for REG: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,024 - ERROR - Error fetching Yahoo Finance data for RVTY: Too Many Requests. Rate limited. Try after a while.
# Screening batch:  79%|█████████████████████████████████████████████████▊             | 395/500 [00:35<00:01, 52.65it/s]2025-08-19 20:45:02,045 - ERROR - Error fetching Yahoo Finance data for REGN: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,045 - ERROR - Error fetching Yahoo Finance data for RMD: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,053 - ERROR - Error fetching Yahoo Finance data for RF: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,054 - ERROR - Error fetching Yahoo Finance data for RSG: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,070 - WARNING - Failed to get TradingView rating for ROL: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,073 - WARNING - Failed to get TradingView rating for ROK: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,077 - WARNING - Failed to get TradingView rating for ROP: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,080 - WARNING - Failed to get TradingView rating for ROST: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,102 - WARNING - Failed to get TradingView rating for RCL: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,105 - WARNING - Failed to get TradingView rating for SPGI: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,105 - WARNING - Failed to get TradingView rating for SBAC: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,105 - ERROR - Error fetching Yahoo Finance data for ROL: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,105 - WARNING - Failed to get TradingView rating for CRM: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,133 - ERROR - Error fetching Yahoo Finance data for ROST: Too Many Requests. Rate limited. Try after a while.
# Screening batch:  80%|██████████████████████████████████████████████████▌            | 401/500 [00:36<00:01, 53.35it/s]2025-08-19 20:45:02,140 - ERROR - Error fetching Yahoo Finance data for ROP: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,143 - ERROR - Error fetching Yahoo Finance data for ROK: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,152 - ERROR - Error fetching Yahoo Finance data for RCL: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,186 - ERROR - Error fetching Yahoo Finance data for SBAC: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,187 - WARNING - Failed to get TradingView rating for SLB: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,187 - ERROR - Error fetching Yahoo Finance data for SPGI: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,189 - ERROR - Error fetching Yahoo Finance data for CRM: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,204 - WARNING - Failed to get TradingView rating for SRE: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,204 - WARNING - Failed to get TradingView rating for STX: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,204 - WARNING - Failed to get TradingView rating for NOW: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,233 - ERROR - Error fetching Yahoo Finance data for SLB: Too Many Requests. Rate limited. Try after a while.
# Screening batch:  82%|███████████████████████████████████████████████████▍           | 408/500 [00:36<00:01, 57.29it/s]2025-08-19 20:45:02,241 - WARNING - Failed to get TradingView rating for SHW: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,241 - WARNING - Failed to get TradingView rating for SWKS: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,249 - WARNING - Failed to get TradingView rating for SJM: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,252 - WARNING - Failed to get TradingView rating for SPG: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,254 - ERROR - Error fetching Yahoo Finance data for STX: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,258 - ERROR - Error fetching Yahoo Finance data for NOW: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,259 - ERROR - Error fetching Yahoo Finance data for SRE: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,281 - ERROR - Error fetching Yahoo Finance data for SHW: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,287 - WARNING - Failed to get TradingView rating for SW: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,304 - ERROR - Error fetching Yahoo Finance data for SPG: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,304 - ERROR - Error fetching Yahoo Finance data for SJM: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,307 - ERROR - Error fetching Yahoo Finance data for SWKS: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,311 - WARNING - Failed to get TradingView rating for SOLV: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,312 - WARNING - Failed to get TradingView rating for SNA: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,320 - WARNING - Failed to get TradingView rating for SO: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,335 - ERROR - Error fetching Yahoo Finance data for SW: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,340 - WARNING - Failed to get TradingView rating for LUV: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# Screening batch:  83%|████████████████████████████████████████████████████▍          | 416/500 [00:36<00:01, 62.81it/s]2025-08-19 20:45:02,358 - WARNING - Failed to get TradingView rating for SWK: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,360 - WARNING - Failed to get TradingView rating for SBUX: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,363 - WARNING - Failed to get TradingView rating for STT: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-19 20:45:02,371 - ERROR - Error fetching Yahoo Finance data for SNA: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,389 - ERROR - Error fetching Yahoo Finance data for LUV: Too Many Requests. Rate limited. Try after a while.
# 2025-08-19 20:45:02,392 - WARNING - Failed to get TradingView rating for STLD: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.

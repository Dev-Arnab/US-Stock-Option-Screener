# %%
import requests
import pandas as pd
import time
from bs4 import BeautifulSoup

# Step 1: Get all NASDAQ tickers
def get_nasdaq_tickers():
    url = "https://old.nasdaq.com/screening/companies-by-name.aspx?letter=0&exchange=nasdaq&render=download"
    response = requests.get(url)
    tickers = pd.read_csv(pd.compat.StringIO(response.text))["Symbol"].tolist()
    return tickers

# Step 2: Get TradingView rating for each ticker
def get_tv_rating(ticker):
    url = f"https://www.tradingview.com/symbols/NASDAQ-{ticker}/technicals/"
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)

    if response.status_code != 200:
        return None

    soup = BeautifulSoup(response.text, "html.parser")
    rating_tag = soup.find("span", {"class": "speedometerSignal-pyzN--tL"})  # TradingView rating tag
    if rating_tag:
        return rating_tag.text.strip()
    return None

# Step 3: Main script with timer
def main():
    print("Fetching all NASDAQ tickers...")
    tickers = get_nasdaq_tickers()
    print(f"Found {len(tickers)} tickers.")

    results = []
    start_time = time.time()

    for i, ticker in enumerate(tickers, start=1):
        rating = get_tv_rating(ticker)
        results.append({"Ticker": ticker, "TV_Rating": rating})

        # Progress update every 10 stocks
        if i % 10 == 0:
            elapsed = time.time() - start_time
            avg_time = elapsed / i
            est_total = avg_time * len(tickers)
            est_remaining = est_total - elapsed
            print(f"[{i}/{len(tickers)}] Processed. Elapsed: {elapsed:.1f}s, Remaining: {est_remaining/60:.1f}m")

    df = pd.DataFrame(results)
    df.to_csv("nasdaq_tv_ratings.csv", index=False)
    print("✅ Saved results to nasdaq_tv_ratings.csv")

if __name__ == "__main__":
    main()
# Out:
# Fetching all NASDAQ tickers...

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from tradingview_ta import TA_Handler, Interval
from tqdm import tqdm
from scipy.stats import norm
from concurrent.futures import ThreadPoolExecutor, as_completed
import datetime
import time
import logging
import matplotlib.pyplot as plt
import warnings
from tenacity import retry, stop_after_attempt, wait_exponential
import json

# Dependency check
required_libs = ['yfinance', 'pandas', 'numpy', 'tradingview_ta', 'tqdm', 'scipy', 'matplotlib', 'tenacity']
for lib in required_libs:
    try:
        __import__(lib)
    except ImportError:
        print(f"Error: {lib} is not installed. Install it using 'pip install {lib}'")
        exit(1)

warnings.filterwarnings('ignore')
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# ------------------------------
# CONFIGURATION
# ------------------------------
CONFIG = {
    'MAX_STOCK_PRICE_TO_OWN_100': None,
    'MAX_PREMIUM_PER_CONTRACT': 1000,  # Relaxed from 50000
    'EARNINGS_WITHIN_DAYS': 180,         # Relaxed from 90 to 180 days
    'REQUIRE_TV_BUY': False,             # Allow all TV ratings
    'EXPIRY_DAYS_MIN': 0,                # Relaxed from 5 (allow same-day expiries)
    'EXPIRY_DAYS_MAX': 180,              # Relaxed from 90
    'MAX_WORKERS': 8,
    'TOP_N': 50,
    'SCORE_WEIGHTS': {'tv': 0.3, 'upside': 0.3, 'delta': 0.2, 'iv': 0.2},
    'MIN_OPTION_VOLUME': 1,              # Relaxed from 5
    'MIN_OPTION_OPEN_INTEREST': 10,      # Relaxed from 50
    'MIN_DELTA': 0.1,                    # Relaxed from 0.2
    'MAX_DELTA': 0.9,                    # Relaxed from 0.8
    'RISK_FREE_RATE': 0.02,
    'DIVIDEND_YIELD': 0.0,
    'MIN_MARKET_CAP': 100_000_000       # New: Minimum market cap $100M
}

# ------------------------------
# Track filter failures
# ------------------------------
FILTER_FAILURES = {
    'tv_rating': 0,
    'price': 0,
    'earnings': 0,
    'options_empty': 0,
    'options_filtered': 0,
    'api_error': 0,
    'market_cap': 0
}

# ------------------------------
# Timer decorator
# ------------------------------
def timed(func):
    def wrapper(*args, **kwargs):
        start = time.time()
        result = func(*args, **kwargs)
        end = time.time()
        logging.info(f"Execution time for {func.__name__}: {end - start:.2f} seconds")
        return result
    return wrapper

# ------------------------------
# Get TradingView rating
# ------------------------------
@retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=4, max=10))
def get_tv_rating(symbol):
    try:
        handler = TA_Handler(symbol=symbol, screener='america', exchange='NASDAQ', interval=Interval.INTERVAL_1_DAY)
        analysis = handler.get_analysis()
        rating = analysis.summary['RECOMMEND']
        score_map = {'STRONG_BUY': 1.0, 'BUY': 0.8, 'NEUTRAL': 0.5, 'SELL': 0.2, 'STRONG_SELL': 0.0}
        return {'rating': rating, 'score': score_map.get(rating, 0.5)}
    except Exception as e:
        FILTER_FAILURES['api_error'] += 1
        logging.warning(f"Failed to get TradingView rating for {symbol}: {str(e)}")
        return {'rating': None, 'score': 0.5}

# ------------------------------
# Fetch Yahoo Finance data
# ------------------------------
def get_yf_data(symbol):
    try:
        stock = yf.Ticker(symbol)
        info = stock.info
        current_price = info.get('regularMarketPrice') or info.get('currentPrice')
        if not current_price or current_price * 100 > CONFIG['MAX_STOCK_PRICE_TO_OWN_100']:
            FILTER_FAILURES['price'] += 1
            logging.info(f"Skipping {symbol}: Invalid price or too expensive")
            return None
        # Market cap filter
        market_cap = info.get('marketCap')
        if market_cap is None or market_cap < CONFIG['MIN_MARKET_CAP']:
            FILTER_FAILURES['market_cap'] += 1
            logging.info(f"Skipping {symbol}: Market cap too low or missing")
            return None
        target_price = info.get('targetMeanPrice')
        # Earnings date handling
        earnings_date = None
        if 'earningsDate' in info and info['earningsDate']:
            earnings_date = info['earningsDate']
            if isinstance(earnings_date, list):
                earnings_date = earnings_date[0] if earnings_date else None
            try:
                earnings_date = pd.to_datetime(earnings_date)
                days_until_earnings = (earnings_date - datetime.datetime.now()).days
                if days_until_earnings > CONFIG['EARNINGS_WITHIN_DAYS']:
                    FILTER_FAILURES['earnings'] += 1
                    logging.info(f"Skipping {symbol}: Earnings too far ({days_until_earnings} days)")
                    return None
            except (ValueError, TypeError):
                logging.warning(f"Invalid earnings date for {symbol}, treating as None")
                earnings_date = None
        # Options
        options_df = pd.DataFrame()
        options = stock.options
        if not options:
            FILTER_FAILURES['options_empty'] += 1
            logging.info(f"Skipping {symbol}: No options available")
            return None
        option_data = []
        for exp in options:
            days_to_expiry = (pd.to_datetime(exp) - datetime.datetime.now()).days
            if CONFIG['EXPIRY_DAYS_MIN'] <= days_to_expiry <= CONFIG['EXPIRY_DAYS_MAX']:
                try:
                    calls = stock.option_chain(exp).calls
                    if calls.empty:
                        continue
                    calls['expirationDate'] = exp
                    calls['type'] = 'call'
                    T = days_to_expiry / 365.0
                    if T <= 0:
                        continue
                    S = current_price
                    strikes = calls['strike'].values
                    ivs = np.where(calls['impliedVolatility'].values > 0, calls['impliedVolatility'].values, 0.3)
                    d1 = (np.log(S / strikes) + (CONFIG['RISK_FREE_RATE'] - CONFIG['DIVIDEND_YIELD'] + 0.5 * ivs**2) * T) / (ivs * np.sqrt(T))
                    calls['delta'] = norm.cdf(d1)
                    calls['gamma'] = norm.pdf(d1) / (S * ivs * np.sqrt(T))
                    calls['theta'] = -(S * norm.pdf(d1) * ivs) / (2 * np.sqrt(T))
                    calls['vega'] = S * norm.pdf(d1) * np.sqrt(T)
                    option_data.append(calls)
                except Exception as e:
                    logging.warning(f"Error fetching options for {symbol} expiry {exp}: {str(e)}")
                    continue
        if option_data:
            options_df = pd.concat(option_data, ignore_index=True)
        return {'symbol': symbol, 'price': current_price, 'target_price': target_price, 'earnings_date': earnings_date, 'options': options_df}
    except Exception as e:
        FILTER_FAILURES['api_error'] += 1
        logging.error(f"Error fetching Yahoo Finance data for {symbol}: {str(e)}")
        return None

# ------------------------------
# Screen a single ticker
# ------------------------------
def screen_ticker(symbol):
    tv = get_tv_rating(symbol)
    if CONFIG['REQUIRE_TV_BUY'] and tv['rating'] not in ['BUY', 'STRONG_BUY']:
        FILTER_FAILURES['tv_rating'] += 1
        logging.info(f"Skipping {symbol}: TV rating {tv['rating']} not BUY/STRONG_BUY")
        return None
    yfdata = get_yf_data(symbol)
    if yfdata is None:
        return None
    # Filter options
    if not yfdata['options'].empty:
        valid_options = yfdata['options'][
            (yfdata['options']['volume'].fillna(0) >= CONFIG['MIN_OPTION_VOLUME']) &
            (yfdata['options']['openInterest'].fillna(0) >= CONFIG['MIN_OPTION_OPEN_INTEREST']) &
            (yfdata['options']['delta'].between(CONFIG['MIN_DELTA'], CONFIG['MAX_DELTA'])) &
            (yfdata['options']['lastPrice'] <= CONFIG['MAX_PREMIUM_PER_CONTRACT'] / 100)
        ]
        if valid_options.empty:
            logging.info(f"Using default option values for {symbol} (no valid options)")
            cop = 50
            iv_score = 0.3
            delta_score = 0.5
            strike = yfdata['price']
            premium = 0
            expiration = None
        else:
            top_call = valid_options.sort_values(by='delta', ascending=False).iloc[0]
            cop = top_call['delta'] * 100
            iv_score = min(top_call['impliedVolatility'] / 0.5, 1.0)
            delta_score = min(max(top_call['delta'], 0), 1)
            strike = top_call['strike']
            premium = top_call['lastPrice']
            expiration = top_call['expirationDate']
    else:
        logging.info(f"Using default option values for {symbol} (no options data)")
        cop = 50
        iv_score = 0.3
        delta_score = 0.5
        strike = yfdata['price']
        premium = 0
    # Upside
    upside = (yfdata['target_price'] / yfdata['price']) if yfdata['target_price'] else 1.0
    upside_score = min(max((upside - 1) / 1.0, 0), 1)
    # Score
    score = (CONFIG['SCORE_WEIGHTS']['tv'] * tv['score'] +
             CONFIG['SCORE_WEIGHTS']['upside'] * upside_score +
             CONFIG['SCORE_WEIGHTS']['delta'] * delta_score +
             CONFIG['SCORE_WEIGHTS']['iv'] * iv_score)
    return {
        'symbol': yfdata['symbol'],
        'price': yfdata['price'],
        'cost_100_shares': yfdata['price'] * 100,
        'target_price': yfdata['target_price'],
        'earnings_date': yfdata['earnings_date'],
        'tv_rating': tv['rating'],
        'score': score,
        'chance_of_profit': cop,
        'iv': iv_score,
        'delta': delta_score,
        'strike': strike,
        'expiration_date': expiration,
        'premium': premium
    }

# ------------------------------
# Run the screener for a batch of tickers
# ------------------------------
def run_screener_from_csv_batch(tickers):
    results = []
    with ThreadPoolExecutor(max_workers=CONFIG['MAX_WORKERS']) as executor:
        futures = {executor.submit(screen_ticker, t): t for t in tickers}
        for f in tqdm(as_completed(futures), total=len(futures), desc="Screening batch"):
            r = f.result()
            if r:
                results.append(r)
    return pd.DataFrame(results)

# ------------------------------
# Run the screener with batch processing
# ------------------------------
@timed
def run_screener_from_csv(csv_file='all_stocks.csv', batch_size=500):
    try:
        df = pd.read_csv(csv_file)
        if 'Symbol' not in df.columns:
            raise ValueError("CSV file must contain a 'Symbol' column")
        tickers = df['Symbol'].tolist()
    except FileNotFoundError:
        logging.error(f"CSV file {csv_file} not found")
        return pd.DataFrame()
    except pd.errors.EmptyDataError:
        logging.error(f"CSV file {csv_file} is empty")
        return pd.DataFrame()
    logging.info(f"Processing {len(tickers)} tickers in batches of {batch_size}")
    results = []
    for i in range(0, len(tickers), batch_size):
        batch = tickers[i:i+batch_size]
        logging.info(f"Processing batch {i//batch_size + 1}: {len(batch)} tickers")
        df_batch = run_screener_from_csv_batch(batch)
        if not df_batch.empty:
            results.append(df_batch)
    if not results:
        print("No stocks passed the screening")
        print("\nFilter Failure Counts:")
        print(json.dumps(FILTER_FAILURES, indent=2))
        return pd.DataFrame()
    df_results = pd.concat(results).sort_values(by='score', ascending=False).head(CONFIG['TOP_N'])
    # Save results
    date_str = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M")
    output_file = f"us_stock_options_screened_{date_str}.csv"

    df_results.to_csv(output_file, index=False)
    print(f"Results saved to {output_file}")
    # Print summary
    if not df_results.empty:
        print("\nTop 5 Stocks by Score:")
        print(df_results[['symbol', 'price', 'cost_100_shares', 'tv_rating', 'score', 'chance_of_profit']].head())
        # Plot top 10 stocks
        if len(df_results) >= 5:
            top_10 = df_results.head(10)
            plt.figure(figsize=(10, 6))
            plt.bar(top_10['symbol'], top_10['score'], color='green', edgecolor='darkgreen')
            plt.title('Top 10 Stocks by Score')
            plt.xlabel('Symbol')
            plt.ylabel('Score')
            plt.xticks(rotation=45)
            plt.tight_layout()
            plt.show()
    return df_results

# ------------------------------
# Manual stock check
# ------------------------------
def check_stock(symbol):
    result = screen_ticker(symbol)
    if result:
        df = pd.DataFrame([result])
        print(df[['symbol', 'price', 'cost_100_shares', 'tv_rating', 'score', 'chance_of_profit']])
    else:
        print(f"{symbol} did not pass basic filters (price/earnings/TV/market_cap)")

# ------------------------------
# Test calculations
# ------------------------------
def test_calculations():
    symbol = 'AAPL'
    data = get_yf_data(symbol)
    if data and not data['options'].empty:
        top_call = data['options'].iloc[0]
        assert 0 <= top_call['delta'] <= 1, f"Delta out of range for {symbol}"
        logging.info(f"Test passed for {symbol}: Delta={top_call['delta']:.2f}")

# ------------------------------
# Example usage
# ----------------------
if __name__ == "__main__":
    test_calculations()
    # df_all = run_screener_from_csv('all_stocks.csv', batch_size=500)
    # check_stock('AAPL')
# Out:
# 2025-08-18 01:42:08,988 - ERROR - Error fetching Yahoo Finance data for AAPL: '>' not supported between instances of 'float' and 'NoneType'

# %%
run_screener_from_csv()
# Out:
# 2025-08-18 01:25:29,747 - INFO - Processing 517 tickers in batches of 500
# 2025-08-18 01:25:29,747 - INFO - Processing batch 1: 500 tickers
# Screening batch:   0%|                                                                         | 0/500 [00:00<?, ?it/s]2025-08-18 01:25:29,810 - WARNING - Failed to get TradingView rating for ABBV: Exchange or symbol not found.
# 2025-08-18 01:25:29,812 - WARNING - Failed to get TradingView rating for MMM: Exchange or symbol not found.
# 2025-08-18 01:25:29,813 - WARNING - Failed to get TradingView rating for ACN: Exchange or symbol not found.
# 2025-08-18 01:25:29,821 - WARNING - Failed to get TradingView rating for AES: Exchange or symbol not found.
# 2025-08-18 01:25:29,824 - WARNING - Failed to get TradingView rating for AOS: Exchange or symbol not found.
# 2025-08-18 01:25:29,826 - WARNING - Failed to get TradingView rating for AMD: 'RECOMMEND'
# 2025-08-18 01:25:29,856 - WARNING - Failed to get TradingView rating for ABT: Exchange or symbol not found.
# 2025-08-18 01:25:29,858 - WARNING - Failed to get TradingView rating for ADBE: 'RECOMMEND'
# 2025-08-18 01:25:30,056 - INFO - Skipping ABBV: Invalid price or too expensive
# Screening batch:   0%|▏                                                                | 1/500 [00:00<02:21,  3.52it/s]2025-08-18 01:25:30,085 - INFO - Skipping AMD: Invalid price or too expensive
# 2025-08-18 01:25:30,088 - INFO - Skipping MMM: Invalid price or too expensive
# 2025-08-18 01:25:30,102 - INFO - Skipping ABT: Invalid price or too expensive
# 2025-08-18 01:25:30,108 - WARNING - Failed to get TradingView rating for AFL: Exchange or symbol not found.
# 2025-08-18 01:25:30,114 - INFO - Skipping ACN: Invalid price or too expensive
# 2025-08-18 01:25:30,119 - INFO - Skipping AOS: Invalid price or too expensive
# 2025-08-18 01:25:30,136 - WARNING - Failed to get TradingView rating for APD: Exchange or symbol not found.
# 2025-08-18 01:25:30,138 - INFO - Skipping ADBE: Invalid price or too expensive
# 2025-08-18 01:25:30,149 - WARNING - Failed to get TradingView rating for ABNB: 'RECOMMEND'
# 2025-08-18 01:25:30,164 - WARNING - Failed to get TradingView rating for AKAM: 'RECOMMEND'
# 2025-08-18 01:25:30,173 - WARNING - Failed to get TradingView rating for ALB: Exchange or symbol not found.
# 2025-08-18 01:25:30,178 - WARNING - Failed to get TradingView rating for A: Exchange or symbol not found.
# 2025-08-18 01:25:30,227 - WARNING - Failed to get TradingView rating for ARE: Exchange or symbol not found.
# 2025-08-18 01:25:30,326 - INFO - Skipping AFL: Invalid price or too expensive
# Screening batch:   2%|█                                                                | 8/500 [00:00<00:29, 16.42it/s]2025-08-18 01:25:30,340 - INFO - Skipping AKAM: Invalid price or too expensive
# 2025-08-18 01:25:30,342 - INFO - Skipping ABNB: Invalid price or too expensive
# 2025-08-18 01:25:30,354 - INFO - Skipping APD: Invalid price or too expensive
# 2025-08-18 01:25:30,373 - INFO - Skipping ALB: Invalid price or too expensive
# 2025-08-18 01:25:30,381 - WARNING - Failed to get TradingView rating for ALGN: 'RECOMMEND'
# 2025-08-18 01:25:30,391 - WARNING - Failed to get TradingView rating for ALLE: Exchange or symbol not found.
# 2025-08-18 01:25:30,397 - INFO - Skipping A: Invalid price or too expensive
# 2025-08-18 01:25:30,413 - WARNING - Failed to get TradingView rating for ALL: Exchange or symbol not found.
# 2025-08-18 01:25:30,423 - INFO - Skipping ARE: Invalid price or too expensive
# 2025-08-18 01:25:30,439 - WARNING - Failed to get TradingView rating for LNT: 'RECOMMEND'
# 2025-08-18 01:25:30,472 - WARNING - Failed to get TradingView rating for MO: Exchange or symbol not found.
# 2025-08-18 01:25:30,473 - WARNING - Failed to get TradingView rating for GOOGL: 'RECOMMEND'
# 2025-08-18 01:25:30,489 - WARNING - Failed to get TradingView rating for GOOG: 'RECOMMEND'
# 2025-08-18 01:25:30,558 - INFO - Skipping ALGN: Invalid price or too expensive
# Screening batch:   3%|█▉                                                              | 15/500 [00:00<00:21, 22.13it/s]2025-08-18 01:25:30,599 - INFO - Skipping ALLE: Invalid price or too expensive
# 2025-08-18 01:25:30,610 - WARNING - Failed to get TradingView rating for AMZN: 'RECOMMEND'
# 2025-08-18 01:25:30,646 - INFO - Skipping ALL: Invalid price or too expensive
# 2025-08-18 01:25:30,648 - INFO - Skipping LNT: Invalid price or too expensive
# 2025-08-18 01:25:30,718 - WARNING - Failed to get TradingView rating for AMCR: Exchange or symbol not found.
# 2025-08-18 01:25:30,723 - INFO - Skipping MO: Invalid price or too expensive
# Screening batch:   4%|██▍                                                             | 19/500 [00:00<00:21, 22.74it/s]2025-08-18 01:25:30,724 - INFO - Skipping GOOGL: Invalid price or too expensive
# 2025-08-18 01:25:30,740 - INFO - Skipping GOOG: Invalid price or too expensive
# 2025-08-18 01:25:30,743 - WARNING - Failed to get TradingView rating for AEP: 'RECOMMEND'
# 2025-08-18 01:25:30,787 - WARNING - Failed to get TradingView rating for AXP: Exchange or symbol not found.
# 2025-08-18 01:25:30,787 - WARNING - Failed to get TradingView rating for AMT: Exchange or symbol not found.
# 2025-08-18 01:25:30,792 - WARNING - Failed to get TradingView rating for AIG: Exchange or symbol not found.
# 2025-08-18 01:25:30,829 - INFO - Skipping AMZN: Invalid price or too expensive
# Screening batch:   4%|██▊                                                             | 22/500 [00:01<00:19, 23.98it/s]2025-08-18 01:25:30,835 - WARNING - Failed to get TradingView rating for AEE: Exchange or symbol not found.
# 2025-08-18 01:25:30,925 - WARNING - Failed to get TradingView rating for AWK: Exchange or symbol not found.
# 2025-08-18 01:25:30,947 - INFO - Skipping AEP: Invalid price or too expensive
# 2025-08-18 01:25:30,994 - WARNING - Failed to get TradingView rating for AMP: Exchange or symbol not found.
# 2025-08-18 01:25:30,994 - INFO - Skipping AIG: Invalid price or too expensive
# 2025-08-18 01:25:31,010 - INFO - Skipping AMT: Invalid price or too expensive
# Screening batch:   5%|███▏                                                            | 25/500 [00:01<00:22, 21.40it/s]2025-08-18 01:25:31,052 - WARNING - Failed to get TradingView rating for AME: Exchange or symbol not found.
# 2025-08-18 01:25:31,057 - INFO - Skipping AEE: Invalid price or too expensive
# 2025-08-18 01:25:31,065 - WARNING - Failed to get TradingView rating for AMGN: 'RECOMMEND'
# 2025-08-18 01:25:31,077 - INFO - Skipping AXP: Invalid price or too expensive
# 2025-08-18 01:25:31,084 - WARNING - Failed to get TradingView rating for APH: Exchange or symbol not found.
# 2025-08-18 01:25:31,129 - INFO - Skipping AWK: Invalid price or too expensive
# Screening batch:   6%|███▋                                                            | 29/500 [00:01<00:19, 24.41it/s]2025-08-18 01:25:31,146 - WARNING - Failed to get TradingView rating for AON: Exchange or symbol not found.
# 2025-08-18 01:25:31,159 - WARNING - Failed to get TradingView rating for ADI: 'RECOMMEND'
# 2025-08-18 01:25:31,181 - WARNING - Failed to get TradingView rating for APA: 'RECOMMEND'
# 2025-08-18 01:25:31,195 - INFO - Skipping AMP: Invalid price or too expensive
# 2025-08-18 01:25:31,239 - WARNING - Failed to get TradingView rating for APO: Exchange or symbol not found.
# 2025-08-18 01:25:31,279 - INFO - Skipping AME: Invalid price or too expensive
# 2025-08-18 01:25:31,307 - INFO - Skipping APH: Invalid price or too expensive
# Screening batch:   6%|████                                                            | 32/500 [00:01<00:22, 21.24it/s]2025-08-18 01:25:31,337 - WARNING - Failed to get TradingView rating for AAPL: 'RECOMMEND'
# 2025-08-18 01:25:31,338 - INFO - Skipping AON: Invalid price or too expensive
# 2025-08-18 01:25:31,394 - WARNING - Failed to get TradingView rating for APTV: Exchange or symbol not found.
# 2025-08-18 01:25:31,399 - INFO - Skipping AMGN: Invalid price or too expensive
# 2025-08-18 01:25:31,404 - INFO - Skipping ADI: Invalid price or too expensive
# 2025-08-18 01:25:31,439 - WARNING - Failed to get TradingView rating for AMAT: 'RECOMMEND'
# 2025-08-18 01:25:31,452 - WARNING - Failed to get TradingView rating for ADM: Exchange or symbol not found.
# 2025-08-18 01:25:31,454 - WARNING - Failed to get TradingView rating for ANET: Exchange or symbol not found.
# 2025-08-18 01:25:31,458 - WARNING - Failed to get TradingView rating for ACGL: 'RECOMMEND'
# 2025-08-18 01:25:31,465 - INFO - Skipping APO: Invalid price or too expensive
# Screening batch:   7%|████▋                                                           | 37/500 [00:01<00:18, 25.01it/s]2025-08-18 01:25:31,487 - INFO - Skipping AAPL: Invalid price or too expensive
# 2025-08-18 01:25:31,540 - WARNING - Failed to get TradingView rating for AIZ: Exchange or symbol not found.
# 2025-08-18 01:25:31,557 - WARNING - Failed to get TradingView rating for AJG: Exchange or symbol not found.
# 2025-08-18 01:25:31,640 - INFO - Skipping APTV: Invalid price or too expensive
# 2025-08-18 01:25:31,649 - INFO - Skipping AMAT: Invalid price or too expensive
# 2025-08-18 01:25:31,649 - INFO - Skipping ACGL: Invalid price or too expensive
# Screening batch:   8%|█████                                                           | 40/500 [00:01<00:20, 22.06it/s]2025-08-18 01:25:31,684 - INFO - Skipping ANET: Invalid price or too expensive
# 2025-08-18 01:25:31,689 - WARNING - Failed to get TradingView rating for T: Exchange or symbol not found.
# 2025-08-18 01:25:31,695 - INFO - Skipping ADM: Invalid price or too expensive
# 2025-08-18 01:25:31,702 - WARNING - Failed to get TradingView rating for ADSK: 'RECOMMEND'
# 2025-08-18 01:25:31,737 - WARNING - Failed to get TradingView rating for ADP: 'RECOMMEND'
# 2025-08-18 01:25:31,752 - WARNING - Failed to get TradingView rating for ATO: Exchange or symbol not found.
# 2025-08-18 01:25:31,790 - WARNING - Failed to get TradingView rating for AZO: Exchange or symbol not found.
# 2025-08-18 01:25:31,815 - INFO - Skipping AJG: Invalid price or too expensive
# Screening batch:   9%|█████▋                                                          | 44/500 [00:02<00:20, 22.67it/s]2025-08-18 01:25:31,841 - INFO - Skipping AIZ: Invalid price or too expensive
# 2025-08-18 01:25:31,902 - WARNING - Failed to get TradingView rating for AVY: Exchange or symbol not found.
# 2025-08-18 01:25:31,911 - INFO - Skipping ADSK: Invalid price or too expensive
# 2025-08-18 01:25:31,916 - WARNING - Failed to get TradingView rating for AVB: Exchange or symbol not found.
# 2025-08-18 01:25:31,926 - INFO - Skipping ADP: Invalid price or too expensive
# Screening batch:   9%|██████                                                          | 47/500 [00:02<00:19, 23.62it/s]2025-08-18 01:25:31,958 - WARNING - Failed to get TradingView rating for AXON: 'RECOMMEND'
# 2025-08-18 01:25:31,969 - INFO - Skipping ATO: Invalid price or too expensive
# 2025-08-18 01:25:31,985 - WARNING - Failed to get TradingView rating for BKR: 'RECOMMEND'
# 2025-08-18 01:25:31,997 - INFO - Skipping AZO: Invalid price or too expensive
# 2025-08-18 01:25:32,030 - WARNING - Failed to get TradingView rating for BALL: Exchange or symbol not found.
# 2025-08-18 01:25:32,084 - WARNING - Failed to get TradingView rating for BAC: Exchange or symbol not found.
# 2025-08-18 01:25:32,109 - INFO - Skipping AVB: Invalid price or too expensive
# Screening batch:  10%|██████▍                                                         | 50/500 [00:02<00:21, 21.19it/s]2025-08-18 01:25:32,123 - INFO - Skipping AVY: Invalid price or too expensive
# 2025-08-18 01:25:32,140 - INFO - Skipping AXON: Invalid price or too expensive
# 2025-08-18 01:25:32,163 - WARNING - Failed to get TradingView rating for BAX: Exchange or symbol not found.
# 2025-08-18 01:25:32,181 - WARNING - Failed to get TradingView rating for BDX: Exchange or symbol not found.
# 2025-08-18 01:25:32,200 - WARNING - Failed to get TradingView rating for BRK.B: Exchange or symbol not found.
# 2025-08-18 01:25:32,234 - INFO - Skipping BALL: Invalid price or too expensive
# Screening batch:  11%|██████▊                                                         | 53/500 [00:02<00:20, 21.87it/s]2025-08-18 01:25:32,284 - WARNING - Failed to get TradingView rating for BBY: Exchange or symbol not found.
# 2025-08-18 01:25:32,356 - WARNING - Failed to get TradingView rating for TECH: 'RECOMMEND'
# 2025-08-18 01:25:32,416 - INFO - Skipping BDX: Invalid price or too expensive
# 2025-08-18 01:25:32,429 - INFO - Skipping BRK.B: Invalid price or too expensive
# Screening batch:  11%|███████▏                                                        | 56/500 [00:02<00:22, 19.55it/s]2025-08-18 01:25:32,477 - WARNING - Failed to get TradingView rating for BIIB: 'RECOMMEND'
# 2025-08-18 01:25:32,508 - INFO - Skipping BBY: Invalid price or too expensive
# 2025-08-18 01:25:32,547 - WARNING - Failed to get TradingView rating for BLK: Exchange or symbol not found.
# 2025-08-18 01:25:32,573 - WARNING - Failed to get TradingView rating for BX: Exchange or symbol not found.
# 2025-08-18 01:25:32,576 - INFO - Skipping TECH: Invalid price or too expensive
# 2025-08-18 01:25:32,623 - WARNING - Failed to get TradingView rating for XYZ: Exchange or symbol not found.
# 2025-08-18 01:25:32,672 - INFO - Skipping BIIB: Invalid price or too expensive
# Screening batch:  12%|███████▌                                                        | 59/500 [00:02<00:26, 16.73it/s]2025-08-18 01:25:32,756 - WARNING - Failed to get TradingView rating for BA: Exchange or symbol not found.
# 2025-08-18 01:25:32,766 - INFO - Skipping BX: Invalid price or too expensive
# 2025-08-18 01:25:32,778 - WARNING - Failed to get TradingView rating for BK: Exchange or symbol not found.
# 2025-08-18 01:25:32,788 - INFO - Using default option values for T (no valid options)
# Screening batch:  12%|███████▉                                                        | 62/500 [00:03<00:23, 18.54it/s]2025-08-18 01:25:32,829 - INFO - Skipping BLK: Invalid price or too expensive
# 2025-08-18 01:25:32,846 - WARNING - Failed to get TradingView rating for BSX: Exchange or symbol not found.
# 2025-08-18 01:25:32,855 - INFO - Skipping XYZ: Invalid price or too expensive
# 2025-08-18 01:25:32,860 - WARNING - Failed to get TradingView rating for BKNG: 'RECOMMEND'
# 2025-08-18 01:25:32,881 - WARNING - Failed to get TradingView rating for BMY: Exchange or symbol not found.
# 2025-08-18 01:25:32,942 - INFO - Skipping BA: Invalid price or too expensive
# Screening batch:  13%|████████▎                                                       | 65/500 [00:03<00:23, 18.79it/s]2025-08-18 01:25:32,949 - WARNING - Failed to get TradingView rating for AVGO: 'RECOMMEND'
# 2025-08-18 01:25:32,973 - INFO - Skipping BK: Invalid price or too expensive
# 2025-08-18 01:25:32,996 - WARNING - Failed to get TradingView rating for BR: Exchange or symbol not found.
# 2025-08-18 01:25:33,026 - WARNING - Failed to get TradingView rating for BRO: Exchange or symbol not found.
# 2025-08-18 01:25:33,047 - INFO - Skipping BSX: Invalid price or too expensive
# Screening batch:  13%|████████▌                                                       | 67/500 [00:03<00:22, 18.95it/s]2025-08-18 01:25:33,059 - INFO - Skipping BKNG: Invalid price or too expensive
# 2025-08-18 01:25:33,105 - WARNING - Failed to get TradingView rating for BF.B: Exchange or symbol not found.
# 2025-08-18 01:25:33,120 - WARNING - Failed to get TradingView rating for BLDR: Exchange or symbol not found.
# 2025-08-18 01:25:33,130 - INFO - Skipping AVGO: Invalid price or too expensive
# 2025-08-18 01:25:33,183 - WARNING - Failed to get TradingView rating for BG: Exchange or symbol not found.
# 2025-08-18 01:25:33,187 - INFO - Skipping BR: Invalid price or too expensive
# Screening batch:  14%|████████▉                                                       | 70/500 [00:03<00:22, 19.39it/s]2025-08-18 01:25:33,225 - INFO - Using default option values for BAC (no valid options)
# 2025-08-18 01:25:33,227 - INFO - Skipping BRO: Invalid price or too expensive
# 2025-08-18 01:25:33,256 - WARNING - Failed to get TradingView rating for BXP: Exchange or symbol not found.
# 2025-08-18 01:25:33,276 - WARNING - Failed to get TradingView rating for CHRW: 'RECOMMEND'
# 2025-08-18 01:25:33,276 - WARNING - Failed to get TradingView rating for CDNS: 'RECOMMEND'
# 2025-08-18 01:25:33,289 - INFO - Skipping BF.B: Invalid price or too expensive
# 2025-08-18 01:25:33,324 - WARNING - Failed to get TradingView rating for CZR: 'RECOMMEND'
# 2025-08-18 01:25:33,333 - WARNING - Failed to get TradingView rating for CPT: Exchange or symbol not found.
# 2025-08-18 01:25:33,358 - INFO - Skipping BG: Invalid price or too expensive
# Screening batch:  15%|█████████▌                                                      | 75/500 [00:03<00:18, 23.07it/s]2025-08-18 01:25:33,372 - INFO - Skipping BLDR: Invalid price or too expensive
# 2025-08-18 01:25:33,404 - WARNING - Failed to get TradingView rating for CPB: 'RECOMMEND'
# 2025-08-18 01:25:33,423 - WARNING - Failed to get TradingView rating for COF: Exchange or symbol not found.
# 2025-08-18 01:25:33,448 - INFO - Skipping BXP: Invalid price or too expensive
# 2025-08-18 01:25:33,468 - INFO - Skipping CDNS: Invalid price or too expensive
# Screening batch:  16%|█████████▉                                                      | 78/500 [00:03<00:17, 24.06it/s]2025-08-18 01:25:33,509 - WARNING - Failed to get TradingView rating for CAH: Exchange or symbol not found.
# 2025-08-18 01:25:33,544 - INFO - Skipping CPT: Invalid price or too expensive
# 2025-08-18 01:25:33,558 - INFO - Skipping CHRW: Invalid price or too expensive
# 2025-08-18 01:25:33,567 - WARNING - Failed to get TradingView rating for KMX: Exchange or symbol not found.
# 2025-08-18 01:25:33,615 - WARNING - Failed to get TradingView rating for CARR: Exchange or symbol not found.
# 2025-08-18 01:25:33,625 - INFO - Skipping COF: Invalid price or too expensive
# Screening batch:  16%|██████████▎                                                     | 81/500 [00:03<00:19, 22.03it/s]2025-08-18 01:25:33,637 - WARNING - Failed to get TradingView rating for CCL: Exchange or symbol not found.
# 2025-08-18 01:25:33,686 - WARNING - Failed to get TradingView rating for CAT: Exchange or symbol not found.
# 2025-08-18 01:25:33,720 - INFO - Skipping CAH: Invalid price or too expensive
# 2025-08-18 01:25:33,756 - INFO - Skipping KMX: Invalid price or too expensive
# 2025-08-18 01:25:33,772 - WARNING - Failed to get TradingView rating for CBOE: Exchange or symbol not found.
# 2025-08-18 01:25:33,810 - WARNING - Failed to get TradingView rating for CBRE: Exchange or symbol not found.
# 2025-08-18 01:25:33,848 - INFO - Skipping CARR: Invalid price or too expensive
# Screening batch:  17%|██████████▊                                                     | 84/500 [00:04<00:21, 18.92it/s]2025-08-18 01:25:33,899 - WARNING - Failed to get TradingView rating for CDW: 'RECOMMEND'
# 2025-08-18 01:25:33,901 - INFO - Skipping CAT: Invalid price or too expensive
# 2025-08-18 01:25:33,957 - WARNING - Failed to get TradingView rating for COR: Exchange or symbol not found.
# 2025-08-18 01:25:33,961 - INFO - Skipping CBOE: Invalid price or too expensive
# Screening batch:  17%|███████████                                                     | 86/500 [00:04<00:22, 18.69it/s]2025-08-18 01:25:34,014 - WARNING - Failed to get TradingView rating for CNC: Exchange or symbol not found.
# 2025-08-18 01:25:34,017 - INFO - Skipping CBRE: Invalid price or too expensive
# 2025-08-18 01:25:34,097 - WARNING - Failed to get TradingView rating for CNP: Exchange or symbol not found.
# 2025-08-18 01:25:34,122 - INFO - Skipping CDW: Invalid price or too expensive
# Screening batch:  18%|███████████▍                                                    | 89/500 [00:04<00:22, 18.66it/s]2025-08-18 01:25:34,147 - WARNING - Failed to get TradingView rating for CF: Exchange or symbol not found.
# 2025-08-18 01:25:34,182 - WARNING - Failed to get TradingView rating for CRL: Exchange or symbol not found.
# 2025-08-18 01:25:34,197 - INFO - Skipping COR: Invalid price or too expensive
# 2025-08-18 01:25:34,257 - WARNING - Failed to get TradingView rating for SCHW: Exchange or symbol not found.
# Screening batch:  18%|███████████▋                                                    | 91/500 [00:04<00:25, 16.25it/s]2025-08-18 01:25:34,351 - WARNING - Failed to get TradingView rating for CHTR: 'RECOMMEND'
# 2025-08-18 01:25:34,371 - INFO - Skipping CF: Invalid price or too expensive
# 2025-08-18 01:25:34,395 - INFO - Skipping CRL: Invalid price or too expensive
# 2025-08-18 01:25:34,428 - WARNING - Failed to get TradingView rating for CVX: Exchange or symbol not found.
# 2025-08-18 01:25:34,441 - WARNING - Failed to get TradingView rating for CMG: Exchange or symbol not found.
# 2025-08-18 01:25:34,453 - WARNING - Failed to get TradingView rating for CB: Exchange or symbol not found.
# 2025-08-18 01:25:34,456 - INFO - Skipping SCHW: Invalid price or too expensive
# Screening batch:  19%|████████████▏                                                   | 95/500 [00:04<00:21, 18.93it/s]2025-08-18 01:25:34,509 - WARNING - Failed to get TradingView rating for CHD: Exchange or symbol not found.
# 2025-08-18 01:25:34,565 - INFO - Skipping CHTR: Invalid price or too expensive
# 2025-08-18 01:25:34,645 - INFO - Using default option values for CCL (no valid options)
# Screening batch:  19%|████████████▍                                                   | 97/500 [00:04<00:24, 16.13it/s]2025-08-18 01:25:34,671 - WARNING - Failed to get TradingView rating for CI: Exchange or symbol not found.
# 2025-08-18 01:25:34,676 - INFO - Skipping CB: Invalid price or too expensive
# 2025-08-18 01:25:34,708 - INFO - Skipping CVX: Invalid price or too expensive
# 2025-08-18 01:25:34,711 - WARNING - Failed to get TradingView rating for CINF: 'RECOMMEND'
# 2025-08-18 01:25:34,738 - INFO - Using default option values for CNP (no valid options)
# 2025-08-18 01:25:34,746 - INFO - Skipping CHD: Invalid price or too expensive
# Screening batch:  20%|████████████▋                                                  | 101/500 [00:04<00:19, 20.57it/s]2025-08-18 01:25:34,775 - WARNING - Failed to get TradingView rating for CTAS: 'RECOMMEND'
# 2025-08-18 01:25:34,807 - WARNING - Failed to get TradingView rating for CFG: Exchange or symbol not found.
# 2025-08-18 01:25:34,808 - WARNING - Failed to get TradingView rating for CSCO: 'RECOMMEND'
# 2025-08-18 01:25:34,811 - WARNING - Failed to get TradingView rating for C: Exchange or symbol not found.
# 2025-08-18 01:25:34,915 - INFO - Skipping CI: Invalid price or too expensive
# 2025-08-18 01:25:34,918 - INFO - Skipping CINF: Invalid price or too expensive
# 2025-08-18 01:25:34,980 - WARNING - Failed to get TradingView rating for CLX: Exchange or symbol not found.
# 2025-08-18 01:25:34,981 - WARNING - Failed to get TradingView rating for CME: 'RECOMMEND'
# 2025-08-18 01:25:34,989 - INFO - Skipping C: Invalid price or too expensive
# Screening batch:  21%|█████████████                                                  | 104/500 [00:05<00:22, 17.45it/s]2025-08-18 01:25:35,000 - INFO - Skipping CTAS: Invalid price or too expensive
# 2025-08-18 01:25:35,002 - INFO - Skipping CSCO: Invalid price or too expensive
# 2025-08-18 01:25:35,055 - WARNING - Failed to get TradingView rating for CMS: Exchange or symbol not found.
# 2025-08-18 01:25:35,064 - WARNING - Failed to get TradingView rating for CTSH: 'RECOMMEND'
# 2025-08-18 01:25:35,107 - WARNING - Failed to get TradingView rating for KO: Exchange or symbol not found.
# 2025-08-18 01:25:35,236 - INFO - Skipping CME: Invalid price or too expensive
# Screening batch:  21%|█████████████▍                                                 | 107/500 [00:05<00:25, 15.13it/s]2025-08-18 01:25:35,266 - INFO - Skipping CLX: Invalid price or too expensive
# 2025-08-18 01:25:35,278 - INFO - Skipping CMS: Invalid price or too expensive
# 2025-08-18 01:25:35,330 - WARNING - Failed to get TradingView rating for CL: Exchange or symbol not found.
# 2025-08-18 01:25:35,331 - WARNING - Failed to get TradingView rating for CMCSA: 'RECOMMEND'
# 2025-08-18 01:25:35,346 - INFO - Skipping KO: Invalid price or too expensive
# 2025-08-18 01:25:35,350 - WARNING - Failed to get TradingView rating for CAG: Exchange or symbol not found.
# 2025-08-18 01:25:35,354 - INFO - Skipping CTSH: Invalid price or too expensive
# 2025-08-18 01:25:35,365 - WARNING - Failed to get TradingView rating for COIN: 'RECOMMEND'
# Screening batch:  22%|██████████████                                                 | 112/500 [00:05<00:18, 20.72it/s]2025-08-18 01:25:35,416 - INFO - Using default option values for CFG (no valid options)
# 2025-08-18 01:25:35,441 - WARNING - Failed to get TradingView rating for COP: Exchange or symbol not found.
# 2025-08-18 01:25:35,470 - WARNING - Failed to get TradingView rating for ED: Exchange or symbol not found.
# 2025-08-18 01:25:35,494 - WARNING - Failed to get TradingView rating for STZ: Exchange or symbol not found.
# 2025-08-18 01:25:35,586 - INFO - Skipping CL: Invalid price or too expensive
# 2025-08-18 01:25:35,647 - INFO - Skipping COIN: Invalid price or too expensive
# Screening batch:  23%|██████████████▍                                                | 115/500 [00:05<00:23, 16.57it/s]2025-08-18 01:25:35,678 - WARNING - Failed to get TradingView rating for CEG: 'RECOMMEND'
# 2025-08-18 01:25:35,692 - INFO - Skipping COP: Invalid price or too expensive
# 2025-08-18 01:25:35,705 - INFO - Using default option values for CMG (no valid options)
# 2025-08-18 01:25:35,708 - INFO - Skipping STZ: Invalid price or too expensive
# 2025-08-18 01:25:35,731 - WARNING - Failed to get TradingView rating for COO: 'RECOMMEND'
# 2025-08-18 01:25:35,734 - INFO - Skipping ED: Invalid price or too expensive
# 2025-08-18 01:25:35,765 - WARNING - Failed to get TradingView rating for CPAY: Exchange or symbol not found.
# 2025-08-18 01:25:35,766 - WARNING - Failed to get TradingView rating for CPRT: 'RECOMMEND'
# 2025-08-18 01:25:35,800 - WARNING - Failed to get TradingView rating for CTVA: Exchange or symbol not found.
# 2025-08-18 01:25:35,814 - WARNING - Failed to get TradingView rating for GLW: Exchange or symbol not found.
# 2025-08-18 01:25:35,886 - INFO - Skipping CEG: Invalid price or too expensive
# Screening batch:  24%|███████████████                                                | 120/500 [00:06<00:21, 18.01it/s]2025-08-18 01:25:35,947 - WARNING - Failed to get TradingView rating for CSGP: 'RECOMMEND'
# 2025-08-18 01:25:35,971 - INFO - Skipping CPAY: Invalid price or too expensive
# 2025-08-18 01:25:35,979 - INFO - Skipping CTVA: Invalid price or too expensive
# 2025-08-18 01:25:35,989 - INFO - Skipping COO: Invalid price or too expensive
# Screening batch:  25%|███████████████▍                                               | 123/500 [00:06<00:18, 19.92it/s]2025-08-18 01:25:36,025 - INFO - Skipping GLW: Invalid price or too expensive
# 2025-08-18 01:25:36,049 - WARNING - Failed to get TradingView rating for CRWD: 'RECOMMEND'
# 2025-08-18 01:25:36,062 - WARNING - Failed to get TradingView rating for CTRA: Exchange or symbol not found.
# 2025-08-18 01:25:36,077 - WARNING - Failed to get TradingView rating for COST: 'RECOMMEND'
# 2025-08-18 01:25:36,089 - WARNING - Failed to get TradingView rating for CCI: Exchange or symbol not found.
# 2025-08-18 01:25:36,163 - INFO - Skipping CSGP: Invalid price or too expensive
# 2025-08-18 01:25:36,214 - WARNING - Failed to get TradingView rating for CSX: 'RECOMMEND'
# 2025-08-18 01:25:36,266 - INFO - Skipping CRWD: Invalid price or too expensive
# Screening batch:  25%|███████████████▉                                               | 126/500 [00:06<00:22, 16.32it/s]2025-08-18 01:25:36,271 - INFO - Skipping CCI: Invalid price or too expensive
# 2025-08-18 01:25:36,282 - INFO - Skipping COST: Invalid price or too expensive
# 2025-08-18 01:25:36,319 - WARNING - Failed to get TradingView rating for CMI: Exchange or symbol not found.
# 2025-08-18 01:25:36,330 - WARNING - Failed to get TradingView rating for CVS: Exchange or symbol not found.
# 2025-08-18 01:25:36,342 - WARNING - Failed to get TradingView rating for DHR: Exchange or symbol not found.
# 2025-08-18 01:25:36,357 - INFO - Using default option values for CMCSA (no valid options)
# Screening batch:  26%|████████████████▍                                              | 130/500 [00:06<00:18, 19.49it/s]2025-08-18 01:25:36,445 - WARNING - Failed to get TradingView rating for DDOG: 'RECOMMEND'
# 2025-08-18 01:25:36,456 - WARNING - Failed to get TradingView rating for DRI: Exchange or symbol not found.
# 2025-08-18 01:25:36,528 - INFO - Skipping CMI: Invalid price or too expensive
# 2025-08-18 01:25:36,566 - INFO - Skipping DHR: Invalid price or too expensive
# Screening batch:  27%|████████████████▊                                              | 133/500 [00:06<00:19, 18.83it/s]2025-08-18 01:25:36,572 - INFO - Skipping CVS: Invalid price or too expensive
# 2025-08-18 01:25:36,612 - WARNING - Failed to get TradingView rating for DVA: Exchange or symbol not found.
# 2025-08-18 01:25:36,614 - WARNING - Failed to get TradingView rating for DECK: Exchange or symbol not found.
# 2025-08-18 01:25:36,639 - INFO - Skipping DDOG: Invalid price or too expensive
# 2025-08-18 01:25:36,653 - INFO - Skipping DRI: Invalid price or too expensive
# 2025-08-18 01:25:36,671 - WARNING - Failed to get TradingView rating for DE: Exchange or symbol not found.
# 2025-08-18 01:25:36,685 - WARNING - Failed to get TradingView rating for DAY: Exchange or symbol not found.
# 2025-08-18 01:25:36,701 - WARNING - Failed to get TradingView rating for DELL: Exchange or symbol not found.
# 2025-08-18 01:25:36,720 - WARNING - Failed to get TradingView rating for DAL: Exchange or symbol not found.
# 2025-08-18 01:25:36,846 - INFO - Skipping DECK: Invalid price or too expensive
# Screening batch:  27%|█████████████████▎                                             | 137/500 [00:07<00:21, 17.03it/s]2025-08-18 01:25:36,858 - INFO - Skipping DVA: Invalid price or too expensive
# 2025-08-18 01:25:36,859 - INFO - Skipping DE: Invalid price or too expensive
# 2025-08-18 01:25:36,903 - INFO - Skipping DAY: Invalid price or too expensive
# 2025-08-18 01:25:36,906 - WARNING - Failed to get TradingView rating for DVN: Exchange or symbol not found.
# 2025-08-18 01:25:36,916 - WARNING - Failed to get TradingView rating for DXCM: 'RECOMMEND'
# 2025-08-18 01:25:36,916 - WARNING - Failed to get TradingView rating for FANG: 'RECOMMEND'
# 2025-08-18 01:25:36,919 - INFO - Skipping DELL: Invalid price or too expensive
# 2025-08-18 01:25:36,953 - WARNING - Failed to get TradingView rating for DLR: Exchange or symbol not found.
# 2025-08-18 01:25:36,954 - INFO - Skipping DAL: Invalid price or too expensive
# Screening batch:  28%|█████████████████▉                                             | 142/500 [00:07<00:16, 22.25it/s]2025-08-18 01:25:36,974 - INFO - Using default option values for CTRA (no valid options)
# 2025-08-18 01:25:36,985 - WARNING - Failed to get TradingView rating for DG: Exchange or symbol not found.
# 2025-08-18 01:25:37,011 - WARNING - Failed to get TradingView rating for DLTR: 'RECOMMEND'
# 2025-08-18 01:25:37,040 - WARNING - Failed to get TradingView rating for D: Exchange or symbol not found.
# 2025-08-18 01:25:37,116 - INFO - Skipping FANG: Invalid price or too expensive
# 2025-08-18 01:25:37,132 - INFO - Skipping DXCM: Invalid price or too expensive
# Screening batch:  29%|██████████████████▎                                            | 145/500 [00:07<00:17, 20.68it/s]2025-08-18 01:25:37,135 - INFO - Skipping DLR: Invalid price or too expensive
# 2025-08-18 01:25:37,164 - WARNING - Failed to get TradingView rating for DPZ: 'RECOMMEND'
# 2025-08-18 01:25:37,184 - INFO - Using default option values for CSX (no valid options)
# 2025-08-18 01:25:37,206 - WARNING - Failed to get TradingView rating for DOV: Exchange or symbol not found.
# 2025-08-18 01:25:37,215 - INFO - Skipping DLTR: Invalid price or too expensive
# 2025-08-18 01:25:37,236 - WARNING - Failed to get TradingView rating for DOW: Exchange or symbol not found.
# 2025-08-18 01:25:37,244 - WARNING - Failed to get TradingView rating for DASH: 'RECOMMEND'
# 2025-08-18 01:25:37,256 - INFO - Skipping D: Invalid price or too expensive
# Screening batch:  30%|██████████████████▊                                            | 149/500 [00:07<00:15, 23.32it/s]2025-08-18 01:25:37,262 - INFO - Skipping DG: Invalid price or too expensive
# 2025-08-18 01:25:37,309 - WARNING - Failed to get TradingView rating for DTE: Exchange or symbol not found.
# 2025-08-18 01:25:37,309 - WARNING - Failed to get TradingView rating for DHI: Exchange or symbol not found.
# 2025-08-18 01:25:37,361 - WARNING - Failed to get TradingView rating for DUK: Exchange or symbol not found.
# 2025-08-18 01:25:37,378 - INFO - Skipping DPZ: Invalid price or too expensive
# 2025-08-18 01:25:37,424 - INFO - Skipping DOV: Invalid price or too expensive
# Screening batch:  30%|███████████████████▏                                           | 152/500 [00:07<00:16, 21.69it/s]2025-08-18 01:25:37,434 - WARNING - Failed to get TradingView rating for DD: Exchange or symbol not found.
# 2025-08-18 01:25:37,467 - INFO - Skipping DASH: Invalid price or too expensive
# 2025-08-18 01:25:37,515 - INFO - Skipping DHI: Invalid price or too expensive
# 2025-08-18 01:25:37,520 - WARNING - Failed to get TradingView rating for ETN: Exchange or symbol not found.
# 2025-08-18 01:25:37,520 - WARNING - Failed to get TradingView rating for EMN: Exchange or symbol not found.
# 2025-08-18 01:25:37,531 - INFO - Skipping DTE: Invalid price or too expensive
# Screening batch:  31%|███████████████████▌                                           | 155/500 [00:07<00:14, 23.10it/s]2025-08-18 01:25:37,546 - INFO - Skipping DUK: Invalid price or too expensive
# 2025-08-18 01:25:37,570 - WARNING - Failed to get TradingView rating for EBAY: 'RECOMMEND'
# 2025-08-18 01:25:37,577 - WARNING - Failed to get TradingView rating for ECL: Exchange or symbol not found.
# 2025-08-18 01:25:37,598 - WARNING - Failed to get TradingView rating for EIX: Exchange or symbol not found.
# 2025-08-18 01:25:37,629 - INFO - Skipping DD: Invalid price or too expensive
# 2025-08-18 01:25:37,681 - WARNING - Failed to get TradingView rating for EW: Exchange or symbol not found.
# 2025-08-18 01:25:37,751 - INFO - Skipping EMN: Invalid price or too expensive
# Screening batch:  32%|███████████████████▉                                           | 158/500 [00:07<00:17, 19.37it/s]2025-08-18 01:25:37,756 - INFO - Skipping ETN: Invalid price or too expensive
# 2025-08-18 01:25:37,779 - INFO - Skipping EBAY: Invalid price or too expensive
# 2025-08-18 01:25:37,786 - INFO - Skipping ECL: Invalid price or too expensive
# 2025-08-18 01:25:37,801 - WARNING - Failed to get TradingView rating for EA: 'RECOMMEND'
# 2025-08-18 01:25:37,809 - WARNING - Failed to get TradingView rating for ELV: Exchange or symbol not found.
# 2025-08-18 01:25:37,834 - WARNING - Failed to get TradingView rating for ENPH: 'RECOMMEND'
# 2025-08-18 01:25:37,838 - INFO - Skipping EIX: Invalid price or too expensive
# 2025-08-18 01:25:37,839 - WARNING - Failed to get TradingView rating for EMR: Exchange or symbol not found.
# 2025-08-18 01:25:37,883 - INFO - Skipping EW: Invalid price or too expensive
# Screening batch:  33%|████████████████████▌                                          | 163/500 [00:08<00:14, 24.00it/s]2025-08-18 01:25:37,936 - WARNING - Failed to get TradingView rating for ETR: Exchange or symbol not found.
# 2025-08-18 01:25:37,991 - WARNING - Failed to get TradingView rating for EOG: Exchange or symbol not found.
# 2025-08-18 01:25:37,993 - INFO - Using default option values for DVN (no valid options)
# 2025-08-18 01:25:37,997 - INFO - Skipping EA: Invalid price or too expensive
# 2025-08-18 01:25:38,013 - INFO - Skipping ELV: Invalid price or too expensive
# Screening batch:  33%|████████████████████▉                                          | 166/500 [00:08<00:14, 23.74it/s]2025-08-18 01:25:38,018 - INFO - Skipping EMR: Invalid price or too expensive
# 2025-08-18 01:25:38,062 - WARNING - Failed to get TradingView rating for EPAM: Exchange or symbol not found.
# 2025-08-18 01:25:38,068 - WARNING - Failed to get TradingView rating for EFX: Exchange or symbol not found.
# 2025-08-18 01:25:38,068 - WARNING - Failed to get TradingView rating for EQIX: 'RECOMMEND'
# 2025-08-18 01:25:38,107 - WARNING - Failed to get TradingView rating for EQT: Exchange or symbol not found.
# 2025-08-18 01:25:38,158 - INFO - Skipping ETR: Invalid price or too expensive
# 2025-08-18 01:25:38,202 - INFO - Skipping EOG: Invalid price or too expensive
# Screening batch:  34%|█████████████████████▎                                         | 169/500 [00:08<00:15, 20.98it/s]2025-08-18 01:25:38,209 - WARNING - Failed to get TradingView rating for EQR: Exchange or symbol not found.
# 2025-08-18 01:25:38,244 - INFO - Skipping EQIX: Invalid price or too expensive
# 2025-08-18 01:25:38,262 - WARNING - Failed to get TradingView rating for ERIE: 'RECOMMEND'
# 2025-08-18 01:25:38,279 - INFO - Skipping EPAM: Invalid price or too expensive
# 2025-08-18 01:25:38,281 - INFO - Skipping EFX: Invalid price or too expensive
# 2025-08-18 01:25:38,287 - INFO - Skipping EQT: Invalid price or too expensive
# 2025-08-18 01:25:38,297 - WARNING - Failed to get TradingView rating for ESS: Exchange or symbol not found.
# 2025-08-18 01:25:38,314 - INFO - Using default option values for DOW (no valid options)
# Screening batch:  35%|█████████████████████▉                                         | 174/500 [00:08<00:12, 26.35it/s]2025-08-18 01:25:38,343 - WARNING - Failed to get TradingView rating for EVRG: 'RECOMMEND'
# 2025-08-18 01:25:38,376 - WARNING - Failed to get TradingView rating for EL: Exchange or symbol not found.
# 2025-08-18 01:25:38,425 - WARNING - Failed to get TradingView rating for ES: Exchange or symbol not found.
# 2025-08-18 01:25:38,439 - INFO - Skipping EQR: Invalid price or too expensive
# 2025-08-18 01:25:38,470 - INFO - Skipping ERIE: Invalid price or too expensive
# 2025-08-18 01:25:38,484 - WARNING - Failed to get TradingView rating for EG: Exchange or symbol not found.
# 2025-08-18 01:25:38,485 - WARNING - Failed to get TradingView rating for EXC: 'RECOMMEND'
# 2025-08-18 01:25:38,522 - INFO - Skipping ESS: Invalid price or too expensive
# Screening batch:  35%|██████████████████████▎                                        | 177/500 [00:08<00:14, 21.85it/s]2025-08-18 01:25:38,530 - WARNING - Failed to get TradingView rating for EXE: 'RECOMMEND'
# 2025-08-18 01:25:38,547 - INFO - Skipping EVRG: Invalid price or too expensive
# 2025-08-18 01:25:38,577 - WARNING - Failed to get TradingView rating for EXPE: 'RECOMMEND'
# 2025-08-18 01:25:38,601 - WARNING - Failed to get TradingView rating for EXPD: Exchange or symbol not found.
# 2025-08-18 01:25:38,636 - INFO - Skipping EL: Invalid price or too expensive
# 2025-08-18 01:25:38,650 - INFO - Skipping ES: Invalid price or too expensive
# Screening batch:  36%|██████████████████████▋                                        | 180/500 [00:08<00:14, 21.95it/s]2025-08-18 01:25:38,690 - WARNING - Failed to get TradingView rating for EXR: Exchange or symbol not found.
# 2025-08-18 01:25:38,698 - INFO - Skipping EXE: Invalid price or too expensive
# 2025-08-18 01:25:38,709 - WARNING - Failed to get TradingView rating for XOM: Exchange or symbol not found.
# 2025-08-18 01:25:38,712 - INFO - Skipping EG: Invalid price or too expensive
# 2025-08-18 01:25:38,784 - INFO - Skipping EXPD: Invalid price or too expensive
# Screening batch:  37%|███████████████████████                                        | 183/500 [00:09<00:14, 22.41it/s]2025-08-18 01:25:38,803 - WARNING - Failed to get TradingView rating for FFIV: 'RECOMMEND'
# 2025-08-18 01:25:38,804 - INFO - Skipping EXPE: Invalid price or too expensive
# 2025-08-18 01:25:38,810 - WARNING - Failed to get TradingView rating for FDS: Exchange or symbol not found.
# 2025-08-18 01:25:38,856 - WARNING - Failed to get TradingView rating for FAST: 'RECOMMEND'
# 2025-08-18 01:25:38,882 - WARNING - Failed to get TradingView rating for FICO: Exchange or symbol not found.
# 2025-08-18 01:25:38,884 - INFO - Skipping EXR: Invalid price or too expensive
# 2025-08-18 01:25:38,891 - INFO - Skipping XOM: Invalid price or too expensive
# Screening batch:  37%|███████████████████████▍                                       | 186/500 [00:09<00:13, 23.81it/s]2025-08-18 01:25:38,933 - WARNING - Failed to get TradingView rating for FRT: Exchange or symbol not found.
# 2025-08-18 01:25:38,943 - WARNING - Failed to get TradingView rating for FDX: Exchange or symbol not found.
# 2025-08-18 01:25:38,977 - INFO - Using default option values for EXC (no valid options)
# 2025-08-18 01:25:39,014 - WARNING - Failed to get TradingView rating for FIS: Exchange or symbol not found.
# 2025-08-18 01:25:39,031 - WARNING - Failed to get TradingView rating for FITB: 'RECOMMEND'
# 2025-08-18 01:25:39,032 - INFO - Skipping FFIV: Invalid price or too expensive
# Screening batch:  38%|███████████████████████▊                                       | 189/500 [00:09<00:13, 22.94it/s]2025-08-18 01:25:39,038 - INFO - Skipping FDS: Invalid price or too expensive
# 2025-08-18 01:25:39,075 - INFO - Skipping FICO: Invalid price or too expensive
# 2025-08-18 01:25:39,103 - WARNING - Failed to get TradingView rating for FE: Exchange or symbol not found.
# 2025-08-18 01:25:39,131 - WARNING - Failed to get TradingView rating for FI: Exchange or symbol not found.
# 2025-08-18 01:25:39,137 - INFO - Skipping FDX: Invalid price or too expensive
# Screening batch:  38%|████████████████████████▏                                      | 192/500 [00:09<00:12, 24.42it/s]2025-08-18 01:25:39,144 - WARNING - Failed to get TradingView rating for FSLR: 'RECOMMEND'
# 2025-08-18 01:25:39,145 - INFO - Skipping FRT: Invalid price or too expensive
# 2025-08-18 01:25:39,200 - WARNING - Failed to get TradingView rating for FTNT: 'RECOMMEND'
# 2025-08-18 01:25:39,231 - WARNING - Failed to get TradingView rating for F: Exchange or symbol not found.
# 2025-08-18 01:25:39,235 - INFO - Skipping FIS: Invalid price or too expensive
# 2025-08-18 01:25:39,286 - WARNING - Failed to get TradingView rating for FTV: Exchange or symbol not found.
# 2025-08-18 01:25:39,331 - INFO - Skipping FI: Invalid price or too expensive
# Screening batch:  39%|████████████████████████▌                                      | 195/500 [00:09<00:14, 20.87it/s]2025-08-18 01:25:39,348 - INFO - Skipping FSLR: Invalid price or too expensive
# 2025-08-18 01:25:39,383 - WARNING - Failed to get TradingView rating for FOXA: 'RECOMMEND'
# 2025-08-18 01:25:39,394 - INFO - Skipping FTNT: Invalid price or too expensive
# 2025-08-18 01:25:39,404 - WARNING - Failed to get TradingView rating for FOX: 'RECOMMEND'
# 2025-08-18 01:25:39,448 - WARNING - Failed to get TradingView rating for BEN: Exchange or symbol not found.
# 2025-08-18 01:25:39,555 - INFO - Using default option values for FAST (no valid options)
# Screening batch:  40%|████████████████████████▉                                      | 198/500 [00:09<00:16, 17.92it/s]2025-08-18 01:25:39,602 - INFO - Skipping FOX: Invalid price or too expensive
# 2025-08-18 01:25:39,630 - INFO - Skipping FOXA: Invalid price or too expensive
# 2025-08-18 01:25:39,649 - WARNING - Failed to get TradingView rating for FCX: Exchange or symbol not found.
# 2025-08-18 01:25:39,684 - WARNING - Failed to get TradingView rating for GRMN: Exchange or symbol not found.
# Screening batch:  40%|█████████████████████████▍                                     | 202/500 [00:09<00:14, 20.79it/s]2025-08-18 01:25:39,688 - WARNING - Failed to get TradingView rating for IT: Exchange or symbol not found.
# 2025-08-18 01:25:39,731 - WARNING - Failed to get TradingView rating for GE: Exchange or symbol not found.
# 2025-08-18 01:25:39,746 - WARNING - Failed to get TradingView rating for GEHC: 'RECOMMEND'
# 2025-08-18 01:25:39,795 - WARNING - Failed to get TradingView rating for GEV: Exchange or symbol not found.
# 2025-08-18 01:25:39,898 - INFO - Skipping GRMN: Invalid price or too expensive
# 2025-08-18 01:25:39,909 - INFO - Skipping IT: Invalid price or too expensive
# Screening batch:  41%|█████████████████████████▊                                     | 205/500 [00:10<00:16, 18.26it/s]2025-08-18 01:25:39,936 - INFO - Skipping GE: Invalid price or too expensive
# 2025-08-18 01:25:39,952 - WARNING - Failed to get TradingView rating for GEN: 'RECOMMEND'
# 2025-08-18 01:25:39,988 - INFO - Skipping GEV: Invalid price or too expensive
# 2025-08-18 01:25:40,002 - WARNING - Failed to get TradingView rating for GNRC: Exchange or symbol not found.
# 2025-08-18 01:25:40,006 - INFO - Skipping GEHC: Invalid price or too expensive
# 2025-08-18 01:25:40,032 - WARNING - Failed to get TradingView rating for GIS: Exchange or symbol not found.
# Screening batch:  42%|██████████████████████████▎                                    | 209/500 [00:10<00:14, 20.43it/s]2025-08-18 01:25:40,091 - WARNING - Failed to get TradingView rating for GM: Exchange or symbol not found.
# 2025-08-18 01:25:40,121 - WARNING - Failed to get TradingView rating for GD: Exchange or symbol not found.
# 2025-08-18 01:25:40,178 - WARNING - Failed to get TradingView rating for GPC: Exchange or symbol not found.
# 2025-08-18 01:25:40,243 - INFO - Skipping GNRC: Invalid price or too expensive
# 2025-08-18 01:25:40,296 - INFO - Skipping GM: Invalid price or too expensive
# 2025-08-18 01:25:40,310 - WARNING - Failed to get TradingView rating for GILD: 'RECOMMEND'
# 2025-08-18 01:25:40,327 - INFO - Skipping GD: Invalid price or too expensive
# Screening batch:  42%|██████████████████████████▋                                    | 212/500 [00:10<00:17, 16.40it/s]2025-08-18 01:25:40,353 - WARNING - Failed to get TradingView rating for GPN: Exchange or symbol not found.
# 2025-08-18 01:25:40,385 - INFO - Skipping GPC: Invalid price or too expensive
# 2025-08-18 01:25:40,391 - WARNING - Failed to get TradingView rating for GL: Exchange or symbol not found.
# 2025-08-18 01:25:40,436 - WARNING - Failed to get TradingView rating for GDDY: Exchange or symbol not found.
# 2025-08-18 01:25:40,536 - INFO - Skipping GILD: Invalid price or too expensive
# Screening batch:  43%|███████████████████████████                                    | 215/500 [00:10<00:17, 16.08it/s]2025-08-18 01:25:40,538 - WARNING - Failed to get TradingView rating for GS: Exchange or symbol not found.
# 2025-08-18 01:25:40,580 - INFO - Skipping GL: Invalid price or too expensive
# 2025-08-18 01:25:40,589 - INFO - Skipping GPN: Invalid price or too expensive
# 2025-08-18 01:25:40,631 - WARNING - Failed to get TradingView rating for HAL: Exchange or symbol not found.
# 2025-08-18 01:25:40,636 - WARNING - Failed to get TradingView rating for HIG: Exchange or symbol not found.
# 2025-08-18 01:25:40,653 - WARNING - Failed to get TradingView rating for HAS: 'RECOMMEND'
# Screening batch:  44%|███████████████████████████▌                                   | 219/500 [00:10<00:14, 19.78it/s]2025-08-18 01:25:40,657 - INFO - Skipping GDDY: Invalid price or too expensive
# 2025-08-18 01:25:40,698 - WARNING - Failed to get TradingView rating for DOC: Exchange or symbol not found.
# 2025-08-18 01:25:40,713 - WARNING - Failed to get TradingView rating for HSIC: 'RECOMMEND'
# 2025-08-18 01:25:40,717 - WARNING - Failed to get TradingView rating for HCA: Exchange or symbol not found.
# 2025-08-18 01:25:40,750 - INFO - Skipping GS: Invalid price or too expensive
# 2025-08-18 01:25:40,800 - WARNING - Failed to get TradingView rating for HSY: Exchange or symbol not found.
# 2025-08-18 01:25:40,821 - INFO - Skipping HIG: Invalid price or too expensive
# Screening batch:  44%|███████████████████████████▉                                   | 222/500 [00:11<00:14, 19.12it/s]2025-08-18 01:25:40,858 - INFO - Skipping HAS: Invalid price or too expensive
# 2025-08-18 01:25:40,875 - WARNING - Failed to get TradingView rating for HPE: Exchange or symbol not found.
# 2025-08-18 01:25:40,883 - INFO - Using default option values for FCX (no valid options)
# 2025-08-18 01:25:40,928 - WARNING - Failed to get TradingView rating for HLT: Exchange or symbol not found.
# 2025-08-18 01:25:40,938 - WARNING - Failed to get TradingView rating for HOLX: 'RECOMMEND'
# ...
# 2025-08-18 01:25:53,508 - INFO - Skipping WMB: Invalid price or too expensive
# 2025-08-18 01:25:53,510 - INFO - Skipping WTW: Invalid price or too expensive
# Screening batch:  98%|█████████████████████████████████████████████████████████████▉ | 492/500 [00:23<00:00, 22.13it/s]2025-08-18 01:25:53,552 - WARNING - Failed to get TradingView rating for XYL: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-18 01:25:53,565 - WARNING - Failed to get TradingView rating for YUM: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-18 01:25:53,587 - INFO - Skipping WDAY: Invalid price or too expensive
# 2025-08-18 01:25:53,650 - INFO - Skipping XEL: Invalid price or too expensive
# 2025-08-18 01:25:53,657 - INFO - Skipping WYNN: Invalid price or too expensive
# Screening batch:  99%|██████████████████████████████████████████████████████████████▎| 495/500 [00:23<00:00, 21.62it/s]2025-08-18 01:25:53,776 - INFO - Skipping YUM: Invalid price or too expensive
# 2025-08-18 01:25:53,797 - INFO - Skipping XYL: Invalid price or too expensive
# Screening batch: 100%|██████████████████████████████████████████████████████████████▋| 498/500 [00:24<00:00, 20.64it/s]2025-08-18 01:25:53,894 - INFO - Using default option values for WBD (no valid options)
# Screening batch: 100%|███████████████████████████████████████████████████████████████| 500/500 [00:24<00:00, 20.73it/s]
# 2025-08-18 01:25:53,902 - INFO - Processing batch 2: 17 tickers
# Screening batch:   0%|                                                                          | 0/17 [00:00<?, ?it/s]2025-08-18 01:25:53,948 - WARNING - Failed to get TradingView rating for ZBRA: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-18 01:25:53,951 - WARNING - Failed to get TradingView rating for ZBH: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-18 01:25:53,952 - WARNING - Failed to get TradingView rating for APP: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-18 01:25:53,956 - WARNING - Failed to get TradingView rating for ZTS: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-18 01:25:53,960 - WARNING - Failed to get TradingView rating for ASML: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-18 01:25:53,963 - WARNING - Failed to get TradingView rating for AZN: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-18 01:25:53,964 - WARNING - Failed to get TradingView rating for ARM: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-18 01:25:53,965 - WARNING - Failed to get TradingView rating for TEAM: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-18 01:25:54,210 - INFO - Skipping ZBRA: Invalid price or too expensive
# Screening batch:   6%|███▉                                                              | 1/17 [00:00<00:04,  3.42it/s]2025-08-18 01:25:54,215 - INFO - Skipping TEAM: Invalid price or too expensive
# 2025-08-18 01:25:54,223 - INFO - Skipping ASML: Invalid price or too expensive
# 2025-08-18 01:25:54,228 - INFO - Skipping ZBH: Invalid price or too expensive
# 2025-08-18 01:25:54,238 - INFO - Skipping ZTS: Invalid price or too expensive
# 2025-08-18 01:25:54,255 - INFO - Skipping AZN: Invalid price or too expensive
# 2025-08-18 01:25:54,259 - WARNING - Failed to get TradingView rating for CCEP: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-18 01:25:54,261 - INFO - Skipping ARM: Invalid price or too expensive
# 2025-08-18 01:25:54,264 - WARNING - Failed to get TradingView rating for GFS: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-18 01:25:54,270 - INFO - Skipping APP: Invalid price or too expensive
# 2025-08-18 01:25:54,273 - WARNING - Failed to get TradingView rating for MELI: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-18 01:25:54,274 - WARNING - Failed to get TradingView rating for MRVL: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-18 01:25:54,285 - WARNING - Failed to get TradingView rating for MSTR: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-18 01:25:54,305 - WARNING - Failed to get TradingView rating for PDD: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-18 01:25:54,311 - WARNING - Failed to get TradingView rating for SHOP: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-18 01:25:54,322 - WARNING - Failed to get TradingView rating for TRI: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-18 01:25:54,453 - INFO - Skipping MELI: Invalid price or too expensive
# Screening batch:  53%|██████████████████████████████████▉                               | 9/17 [00:00<00:00, 19.37it/s]2025-08-18 01:25:54,464 - INFO - Skipping MRVL: Invalid price or too expensive
# 2025-08-18 01:25:54,486 - INFO - Skipping CCEP: Invalid price or too expensive
# 2025-08-18 01:25:54,501 - WARNING - Failed to get TradingView rating for ZS: Can't access TradingView's API. HTTP status code: 429. Check for invalid symbol, exchange, or indicators.
# 2025-08-18 01:25:54,508 - INFO - Skipping SHOP: Invalid price or too expensive
# 2025-08-18 01:25:54,508 - INFO - Skipping TRI: Invalid price or too expensive
# 2025-08-18 01:25:54,509 - INFO - Skipping MSTR: Invalid price or too expensive
# 2025-08-18 01:25:54,515 - INFO - Skipping PDD: Invalid price or too expensive
# 2025-08-18 01:25:54,673 - INFO - Skipping ZS: Invalid price or too expensive
# Screening batch:  94%|█████████████████████████████████████████████████████████████▏   | 16/17 [00:00<00:00, 24.60it/s]2025-08-18 01:25:54,803 - INFO - Using default option values for GFS (no valid options)
# Screening batch: 100%|█████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 19.22it/s]
# Results saved to us_stock_options_screened_2025-08-18_01-25.csv
#
# Top 5 Stocks by Score:
#    symbol  price  cost_100_shares tv_rating     score  chance_of_profit
# 53    MGM  35.92           3592.0      None  0.606774         82.280561
# 76     WY  25.84           2584.0      None  0.600072         82.988936
# 35    HAL  21.12           2112.0      None  0.599475         86.231566
# 48    KEY  18.04           1804.0      None  0.578964         88.471416
# 37   HBAN  16.57           1657.0      None  0.574330         88.628463
# 2025-08-18 01:25:55,002 - INFO - Execution time for run_screener_from_csv: 25.26 seconds
#    symbol   price  cost_100_shares  target_price earnings_date tv_rating  \
# 53    MGM  35.920           3592.0      47.63889          None      None
# 76     WY  25.840           2584.0      33.08333          None      None
# 35    HAL  21.120           2112.0      26.54167          None      None
# 48    KEY  18.040           1804.0      21.16818          None      None
# 37   HBAN  16.570           1657.0      19.17000          None      None
# 3     BKR  42.800           4280.0      50.09524          None      None
# 8     CZR  25.330           2533.0      41.47059          None      None
# 49    KMI  26.670           2667.0      31.06722          None      None
# 45    KDP  34.780           3478.0      38.60000          None      None
# 38    HRL  28.480           2848.0      32.44444          None      None
# 66     SW  42.690           4269.0      56.02857          None      None
# 65     RF  25.600           2560.0      28.42045          None      None
# 30    GEN  31.470           3147.0      33.71900          None      None
# 43     IP  46.600           4660.0      54.15833          None      None
# 75     VZ  44.240           4424.0      48.73938          None      None
# 62    PPL  36.550           3655.0      38.23077          None      None
# 27    FTV  48.160           4816.0      63.00000          None      None
# 25   FITB  42.480           4248.0      48.01136          None      None
# 54   MRNA  28.020           2802.0      45.60000          None      None
# 51    LKQ  30.970           3097.0      43.41667          None      None
# 17   CPRT  47.080           4708.0      58.62500          None      None
# 63    PCG  15.020           1502.0      20.35714          None      None
# 1    AMCR   8.730            873.0      11.04000          None      None
# 5     BAX  24.180           2418.0      29.35733          None      None
# 12    CNC  28.490           2849.0      34.56250          None      None
# 69   SMCI  45.370           4537.0      50.37500          None      None
# 22   ENPH  34.840           3484.0      42.20156          None      None
# 34    HST  15.720           1572.0      18.32353          None      None
# 18   CTRA  24.030           2403.0      33.72000          None      None
# 16    CAG  19.170           1917.0      21.41667          None      None
# 2     APA  20.480           2048.0      23.53571          None      None
# 67    SLB  32.990           3299.0      45.46429          None      None
# 26     FE  43.470           4347.0      45.50000          None      None
# 0     AES  13.310           1331.0      13.83333          None      None
# 20    DVN  33.690           3369.0      44.78571          None      None
# 31    GIS  49.650           4965.0      55.20000          None      None
# 14    CMG  44.040           4404.0      58.25806          None      None
# 47   KVUE  21.200           2120.0      22.80000          None      None
# 7     BMY  48.440           4844.0      53.00000          None      None
# 39    HPQ  26.740           2674.0      27.00133          None      None
# 33    DOC  17.310           1731.0      22.46875          None      None
# 9     CPB  32.510           3251.0      35.20000          None      None
# 40    IPG  26.090           2609.0      32.63750          None      None
# 55   NWSA  29.461           2946.1      36.63333          None      None
# 78    WBD  11.850           1185.0      14.68571          None      None
# 21    DOW  23.360           2336.0      28.94118          None      None
# 59   NCLH  24.300           2430.0      29.97619          None      None
# 56    MOS  32.470           3247.0      39.74737          None      None
# 73   VICI  32.500           3250.0      36.59091          None      None
# 42   INVH  30.540           3054.0      37.15909          None      None
#
#        score  chance_of_profit        iv     delta    strike expiration_date  \
# 53  0.606774         82.280561  0.971690  0.822806    29.000      2025-12-19
# 76  0.600072         82.988936  1.000000  0.829889    20.000      2025-10-17
# 35  0.599475         86.231566  1.000000  0.862316    15.000      2025-12-19
# 48  0.578964         88.471416  1.000000  0.884714    13.000      2025-09-19
# 37  0.574330         88.628463  1.000000  0.886285    10.000      2025-10-17
# 3   0.567428         83.146723  1.000000  0.831467    33.000      2025-11-21
# 8   0.563343         11.089777  1.000000  0.110898    75.000      2026-01-16
# 49  0.556413         78.475115  1.000000  0.784751    21.000      2025-12-19
# 45  0.552213         84.631280  1.000000  0.846313    28.000      2025-10-17
# 38  0.547383         77.811304  1.000000  0.778113    23.000      2026-01-16
# 66  0.545194         69.087385  0.816418  0.690874    40.000      2025-10-17
# 65  0.543261         88.501793  0.916026  0.885018    20.000      2025-11-21
# 30  0.538249         83.404698  1.000000  0.834047    23.000      2026-01-16
# 43  0.538056         69.698517  1.000000  0.696985    42.500      2025-10-17
# 75  0.537217         89.680115  0.886730  0.896801    36.000      2025-10-17
# 62  0.535352         85.778091  1.000000  0.857781    28.000      2025-10-17
# 27  0.508878         33.217980  1.000000  0.332180    70.000      2025-09-19
# 25  0.508084         88.317905  0.711927  0.883179    35.000      2025-11-21
# 54  0.498223         50.000000  0.300000  0.500000    28.020            None
# 51  0.497538         13.484994  1.000000  0.134850    50.000      2025-11-21
# 17  0.487023         76.087151  0.556411  0.760872    42.500      2026-01-16
# 63  0.484196         13.797587  1.000000  0.137976    25.000      2025-12-19
# 1   0.451292         10.955379  1.000000  0.109554    15.000      2025-12-19
# 5   0.448526         17.145747  1.000000  0.171457    47.500      2025-09-19
# 12  0.444248         15.152226  1.000000  0.151522    80.000      2025-12-19
# 69  0.435410         26.157786  1.000000  0.261578  1790.000      2026-01-16
# 22  0.434127         10.368943  1.000000  0.103689   155.000      2026-01-16
# 34  0.433917         17.115412  1.000000  0.171154    20.000      2025-10-17
# 18  0.430974         50.000000  0.300000  0.500000    24.030            None
# 16  0.425009         19.924760  1.000000  0.199248    26.000      2025-12-19
# 2   0.424354         14.796418  1.000000  0.147964    37.500      2025-10-17
# 67  0.423437         50.000000  0.300000  0.500000    32.990            None
# 26  0.420262         79.638271  0.484878  0.796383    39.000      2026-01-16
# 0   0.410215         24.209744  1.000000  0.242097    32.000      2026-01-16
# 20  0.408804         50.000000  0.300000  0.500000    33.690            None
# 31  0.406875         11.670320  1.000000  0.116703    82.500      2026-01-16
# 14  0.406853         50.000000  0.300000  0.500000    44.040            None
# 47  0.403551         15.454579  1.000000  0.154546    35.000      2026-01-16
# 7   0.401814         11.786477  1.000000  0.117865    85.000      2025-09-19
# 39  0.401318         24.192841  1.000000  0.241928    36.000      2025-11-21
# 33  0.399406         50.000000  0.300000  0.500000    17.310            None
# 9   0.397149         11.163103  1.000000  0.111631    55.000      2026-01-16
# 40  0.385287         50.000000  0.300000  0.500000    26.090            None
# 55  0.383036         50.000000  0.300000  0.500000    29.461            None
# 78  0.381790         50.000000  0.300000  0.500000    11.850            None
# 21  0.381676         50.000000  0.300000  0.500000    23.360            None
# 59  0.380076         50.000000  0.300000  0.500000    24.300            None
# 56  0.377238         50.000000  0.300000  0.500000    32.470            None
# 73  0.376315         17.517264  0.767590  0.175173    42.500      2026-01-16
# 42  0.375021         50.000000  0.300000  0.500000    30.540            None
#
#     premium
# 53     9.90
# 76     5.98
# 35     6.90
# 48     3.71
# 37     6.00
# 3      8.10
# 8      0.14
# 49     6.34
# 45     7.00
# 38     7.75
# 66     6.40
# 65     5.90
# 30     7.00
# 43     4.80
# 75     5.63
# 62     7.30
# 27     4.41
# 25     9.71
# 54     0.00
# 51     0.20
# 17     8.90
# 63     0.06
# 1      0.05
# 5      0.05
# 12     0.95
# 69     9.25
# 22     0.30
# 34     0.06
# 18     0.00
# 16     0.10
# 2      0.03
# 67     0.00
# 26     3.00
# 0      0.10
# 20     0.00
# 31     0.30
# 14     0.00
# 47     0.26
# 7      0.04
# 39     0.57
# 33     0.00
# 9      0.20
# 40     0.00
# 55     0.00
# 78     0.00
# 21     0.00
# 59     0.00
# 56     0.00
# 73     0.20
# 42     0.00

# %%
check_stock("BLLSH")
# Out:
# 2025-08-18 01:24:49,084 - WARNING - Failed to get TradingView rating for BLLSH: Exchange or symbol not found.
# 2025-08-18 01:24:49,256 - ERROR - HTTP Error 404:
# 2025-08-18 01:24:49,404 - INFO - Skipping BLLSH: Invalid price or too expensive
# BLLSH did not pass basic filters (price/earnings/TV/market_cap)
